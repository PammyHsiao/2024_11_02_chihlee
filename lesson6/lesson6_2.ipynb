# %%
from openpyxl import load_workbook,Workbook,worksheet
wb:Workbook = load_workbook('aqi.xlsx')
type(wb)
# Out:
# openpyxl.workbook.workbook.Workbook

# %%
sheet:Workbook = wb.worksheets[0]
type(sheet)
sheets:list=[]
for row in sheet:
    print(row)
# Out:
# (<Cell 'aqi'.A1>, <Cell 'aqi'.B1>, <Cell 'aqi'.C1>, <Cell 'aqi'.D1>, <Cell 'aqi'.E1>, <Cell 'aqi'.F1>, <Cell 'aqi'.G1>, <Cell 'aqi'.H1>, <Cell 'aqi'.I1>, <Cell 'aqi'.J1>, <Cell 'aqi'.K1>, <Cell 'aqi'.L1>, <Cell 'aqi'.M1>, <Cell 'aqi'.N1>, <Cell 'aqi'.O1>, <Cell 'aqi'.P1>, <Cell 'aqi'.Q1>, <Cell 'aqi'.R1>, <Cell 'aqi'.S1>, <Cell 'aqi'.T1>, <Cell 'aqi'.U1>, <Cell 'aqi'.V1>, <Cell 'aqi'.W1>, <Cell 'aqi'.X1>, <Cell 'aqi'.Y1>)
# (<Cell 'aqi'.A2>, <Cell 'aqi'.B2>, <Cell 'aqi'.C2>, <Cell 'aqi'.D2>, <Cell 'aqi'.E2>, <Cell 'aqi'.F2>, <Cell 'aqi'.G2>, <Cell 'aqi'.H2>, <Cell 'aqi'.I2>, <Cell 'aqi'.J2>, <Cell 'aqi'.K2>, <Cell 'aqi'.L2>, <Cell 'aqi'.M2>, <Cell 'aqi'.N2>, <Cell 'aqi'.O2>, <Cell 'aqi'.P2>, <Cell 'aqi'.Q2>, <Cell 'aqi'.R2>, <Cell 'aqi'.S2>, <Cell 'aqi'.T2>, <Cell 'aqi'.U2>, <Cell 'aqi'.V2>, <Cell 'aqi'.W2>, <Cell 'aqi'.X2>, <Cell 'aqi'.Y2>)
# (<Cell 'aqi'.A3>, <Cell 'aqi'.B3>, <Cell 'aqi'.C3>, <Cell 'aqi'.D3>, <Cell 'aqi'.E3>, <Cell 'aqi'.F3>, <Cell 'aqi'.G3>, <Cell 'aqi'.H3>, <Cell 'aqi'.I3>, <Cell 'aqi'.J3>, <Cell 'aqi'.K3>, <Cell 'aqi'.L3>, <Cell 'aqi'.M3>, <Cell 'aqi'.N3>, <Cell 'aqi'.O3>, <Cell 'aqi'.P3>, <Cell 'aqi'.Q3>, <Cell 'aqi'.R3>, <Cell 'aqi'.S3>, <Cell 'aqi'.T3>, <Cell 'aqi'.U3>, <Cell 'aqi'.V3>, <Cell 'aqi'.W3>, <Cell 'aqi'.X3>, <Cell 'aqi'.Y3>)
# (<Cell 'aqi'.A4>, <Cell 'aqi'.B4>, <Cell 'aqi'.C4>, <Cell 'aqi'.D4>, <Cell 'aqi'.E4>, <Cell 'aqi'.F4>, <Cell 'aqi'.G4>, <Cell 'aqi'.H4>, <Cell 'aqi'.I4>, <Cell 'aqi'.J4>, <Cell 'aqi'.K4>, <Cell 'aqi'.L4>, <Cell 'aqi'.M4>, <Cell 'aqi'.N4>, <Cell 'aqi'.O4>, <Cell 'aqi'.P4>, <Cell 'aqi'.Q4>, <Cell 'aqi'.R4>, <Cell 'aqi'.S4>, <Cell 'aqi'.T4>, <Cell 'aqi'.U4>, <Cell 'aqi'.V4>, <Cell 'aqi'.W4>, <Cell 'aqi'.X4>, <Cell 'aqi'.Y4>)
# (<Cell 'aqi'.A9>, <Cell 'aqi'.B9>, <Cell 'aqi'.C9>, <Cell 'aqi'.D9>, <Cell 'aqi'.E9>, <Cell 'aqi'.F9>, <Cell 'aqi'.G9>, <Cell 'aqi'.H9>, <Cell 'aqi'.I9>, <Cell 'aqi'.J9>, <Cell 'aqi'.K9>, <Cell 'aqi'.L9>, <Cell 'aqi'.M9>, <Cell 'aqi'.N9>, <Cell 'aqi'.O9>, <Cell 'aqi'.P9>, <Cell 'aqi'.Q9>, <Cell 'aqi'.R9>, <Cell 'aqi'.S9>, <Cell 'aqi'.T9>, <Cell 'aqi'.U9>, <Cell 'aqi'.V9>, <Cell 'aqi'.W9>, <Cell 'aqi'.X9>, <Cell 'aqi'.Y9>)
# (<Cell 'aqi'.A10>, <Cell 'aqi'.B10>, <Cell 'aqi'.C10>, <Cell 'aqi'.D10>, <Cell 'aqi'.E10>, <Cell 'aqi'.F10>, <Cell 'aqi'.G10>, <Cell 'aqi'.H10>, <Cell 'aqi'.I10>, <Cell 'aqi'.J10>, <Cell 'aqi'.K10>, <Cell 'aqi'.L10>, <Cell 'aqi'.M10>, <Cell 'aqi'.N10>, <Cell 'aqi'.O10>, <Cell 'aqi'.P10>, <Cell 'aqi'.Q10>, <Cell 'aqi'.R10>, <Cell 'aqi'.S10>, <Cell 'aqi'.T10>, <Cell 'aqi'.U10>, <Cell 'aqi'.V10>, <Cell 'aqi'.W10>, <Cell 'aqi'.X10>, <Cell 'aqi'.Y10>)
# (<Cell 'aqi'.A11>, <Cell 'aqi'.B11>, <Cell 'aqi'.C11>, <Cell 'aqi'.D11>, <Cell 'aqi'.E11>, <Cell 'aqi'.F11>, <Cell 'aqi'.G11>, <Cell 'aqi'.H11>, <Cell 'aqi'.I11>, <Cell 'aqi'.J11>, <Cell 'aqi'.K11>, <Cell 'aqi'.L11>, <Cell 'aqi'.M11>, <Cell 'aqi'.N11>, <Cell 'aqi'.O11>, <Cell 'aqi'.P11>, <Cell 'aqi'.Q11>, <Cell 'aqi'.R11>, <Cell 'aqi'.S11>, <Cell 'aqi'.T11>, <Cell 'aqi'.U11>, <Cell 'aqi'.V11>, <Cell 'aqi'.W11>, <Cell 'aqi'.X11>, <Cell 'aqi'.Y11>)
# (<Cell 'aqi'.A12>, <Cell 'aqi'.B12>, <Cell 'aqi'.C12>, <Cell 'aqi'.D12>, <Cell 'aqi'.E12>, <Cell 'aqi'.F12>, <Cell 'aqi'.G12>, <Cell 'aqi'.H12>, <Cell 'aqi'.I12>, <Cell 'aqi'.J12>, <Cell 'aqi'.K12>, <Cell 'aqi'.L12>, <Cell 'aqi'.M12>, <Cell 'aqi'.N12>, <Cell 'aqi'.O12>, <Cell 'aqi'.P12>, <Cell 'aqi'.Q12>, <Cell 'aqi'.R12>, <Cell 'aqi'.S12>, <Cell 'aqi'.T12>, <Cell 'aqi'.U12>, <Cell 'aqi'.V12>, <Cell 'aqi'.W12>, <Cell 'aqi'.X12>, <Cell 'aqi'.Y12>)
# (<Cell 'aqi'.A105>, <Cell 'aqi'.B105>, <Cell 'aqi'.C105>, <Cell 'aqi'.D105>, <Cell 'aqi'.E105>, <Cell 'aqi'.F105>, <Cell 'aqi'.G105>, <Cell 'aqi'.H105>, <Cell 'aqi'.I105>, <Cell 'aqi'.J105>, <Cell 'aqi'.K105>, <Cell 'aqi'.L105>, <Cell 'aqi'.M105>, <Cell 'aqi'.N105>, <Cell 'aqi'.O105>, <Cell 'aqi'.P105>, <Cell 'aqi'.Q105>, <Cell 'aqi'.R105>, <Cell 'aqi'.S105>, <Cell 'aqi'.T105>, <Cell 'aqi'.U105>, <Cell 'aqi'.V105>, <Cell 'aqi'.W105>, <Cell 'aqi'.X105>, <Cell 'aqi'.Y105>)
# (<Cell 'aqi'.A106>, <Cell 'aqi'.B106>, <Cell 'aqi'.C106>, <Cell 'aqi'.D106>, <Cell 'aqi'.E106>, <Cell 'aqi'.F106>, <Cell 'aqi'.G106>, <Cell 'aqi'.H106>, <Cell 'aqi'.I106>, <Cell 'aqi'.J106>, <Cell 'aqi'.K106>, <Cell 'aqi'.L106>, <Cell 'aqi'.M106>, <Cell 'aqi'.N106>, <Cell 'aqi'.O106>, <Cell 'aqi'.P106>, <Cell 'aqi'.Q106>, <Cell 'aqi'.R106>, <Cell 'aqi'.S106>, <Cell 'aqi'.T106>, <Cell 'aqi'.U106>, <Cell 'aqi'.V106>, <Cell 'aqi'.W106>, <Cell 'aqi'.X106>, <Cell 'aqi'.Y106>)
# ...
# (<Cell 'aqi'.A969>, <Cell 'aqi'.B969>, <Cell 'aqi'.C969>, <Cell 'aqi'.D969>, <Cell 'aqi'.E969>, <Cell 'aqi'.F969>, <Cell 'aqi'.G969>, <Cell 'aqi'.H969>, <Cell 'aqi'.I969>, <Cell 'aqi'.J969>, <Cell 'aqi'.K969>, <Cell 'aqi'.L969>, <Cell 'aqi'.M969>, <Cell 'aqi'.N969>, <Cell 'aqi'.O969>, <Cell 'aqi'.P969>, <Cell 'aqi'.Q969>, <Cell 'aqi'.R969>, <Cell 'aqi'.S969>, <Cell 'aqi'.T969>, <Cell 'aqi'.U969>, <Cell 'aqi'.V969>, <Cell 'aqi'.W969>, <Cell 'aqi'.X969>, <Cell 'aqi'.Y969>)
# (<Cell 'aqi'.A970>, <Cell 'aqi'.B970>, <Cell 'aqi'.C970>, <Cell 'aqi'.D970>, <Cell 'aqi'.E970>, <Cell 'aqi'.F970>, <Cell 'aqi'.G970>, <Cell 'aqi'.H970>, <Cell 'aqi'.I970>, <Cell 'aqi'.J970>, <Cell 'aqi'.K970>, <Cell 'aqi'.L970>, <Cell 'aqi'.M970>, <Cell 'aqi'.N970>, <Cell 'aqi'.O970>, <Cell 'aqi'.P970>, <Cell 'aqi'.Q970>, <Cell 'aqi'.R970>, <Cell 'aqi'.S970>, <Cell 'aqi'.T970>, <Cell 'aqi'.U970>, <Cell 'aqi'.V970>, <Cell 'aqi'.W970>, <Cell 'aqi'.X970>, <Cell 'aqi'.Y970>)
# (<Cell 'aqi'.A979>, <Cell 'aqi'.B979>, <Cell 'aqi'.C979>, <Cell 'aqi'.D979>, <Cell 'aqi'.E979>, <Cell 'aqi'.F979>, <Cell 'aqi'.G979>, <Cell 'aqi'.H979>, <Cell 'aqi'.I979>, <Cell 'aqi'.J979>, <Cell 'aqi'.K979>, <Cell 'aqi'.L979>, <Cell 'aqi'.M979>, <Cell 'aqi'.N979>, <Cell 'aqi'.O979>, <Cell 'aqi'.P979>, <Cell 'aqi'.Q979>, <Cell 'aqi'.R979>, <Cell 'aqi'.S979>, <Cell 'aqi'.T979>, <Cell 'aqi'.U979>, <Cell 'aqi'.V979>, <Cell 'aqi'.W979>, <Cell 'aqi'.X979>, <Cell 'aqi'.Y979>)
# (<Cell 'aqi'.A980>, <Cell 'aqi'.B980>, <Cell 'aqi'.C980>, <Cell 'aqi'.D980>, <Cell 'aqi'.E980>, <Cell 'aqi'.F980>, <Cell 'aqi'.G980>, <Cell 'aqi'.H980>, <Cell 'aqi'.I980>, <Cell 'aqi'.J980>, <Cell 'aqi'.K980>, <Cell 'aqi'.L980>, <Cell 'aqi'.M980>, <Cell 'aqi'.N980>, <Cell 'aqi'.O980>, <Cell 'aqi'.P980>, <Cell 'aqi'.Q980>, <Cell 'aqi'.R980>, <Cell 'aqi'.S980>, <Cell 'aqi'.T980>, <Cell 'aqi'.U980>, <Cell 'aqi'.V980>, <Cell 'aqi'.W980>, <Cell 'aqi'.X980>, <Cell 'aqi'.Y980>)
# (<Cell 'aqi'.A981>, <Cell 'aqi'.B981>, <Cell 'aqi'.C981>, <Cell 'aqi'.D981>, <Cell 'aqi'.E981>, <Cell 'aqi'.F981>, <Cell 'aqi'.G981>, <Cell 'aqi'.H981>, <Cell 'aqi'.I981>, <Cell 'aqi'.J981>, <Cell 'aqi'.K981>, <Cell 'aqi'.L981>, <Cell 'aqi'.M981>, <Cell 'aqi'.N981>, <Cell 'aqi'.O981>, <Cell 'aqi'.P981>, <Cell 'aqi'.Q981>, <Cell 'aqi'.R981>, <Cell 'aqi'.S981>, <Cell 'aqi'.T981>, <Cell 'aqi'.U981>, <Cell 'aqi'.V981>, <Cell 'aqi'.W981>, <Cell 'aqi'.X981>, <Cell 'aqi'.Y981>)
# (<Cell 'aqi'.A982>, <Cell 'aqi'.B982>, <Cell 'aqi'.C982>, <Cell 'aqi'.D982>, <Cell 'aqi'.E982>, <Cell 'aqi'.F982>, <Cell 'aqi'.G982>, <Cell 'aqi'.H982>, <Cell 'aqi'.I982>, <Cell 'aqi'.J982>, <Cell 'aqi'.K982>, <Cell 'aqi'.L982>, <Cell 'aqi'.M982>, <Cell 'aqi'.N982>, <Cell 'aqi'.O982>, <Cell 'aqi'.P982>, <Cell 'aqi'.Q982>, <Cell 'aqi'.R982>, <Cell 'aqi'.S982>, <Cell 'aqi'.T982>, <Cell 'aqi'.U982>, <Cell 'aqi'.V982>, <Cell 'aqi'.W982>, <Cell 'aqi'.X982>, <Cell 'aqi'.Y982>)
# (<Cell 'aqi'.A1000>, <Cell 'aqi'.B1000>, <Cell 'aqi'.C1000>, <Cell 'aqi'.D1000>, <Cell 'aqi'.E1000>, <Cell 'aqi'.F1000>, <Cell 'aqi'.G1000>, <Cell 'aqi'.H1000>, <Cell 'aqi'.I1000>, <Cell 'aqi'.J1000>, <Cell 'aqi'.K1000>, <Cell 'aqi'.L1000>, <Cell 'aqi'.M1000>, <Cell 'aqi'.N1000>, <Cell 'aqi'.O1000>, <Cell 'aqi'.P1000>, <Cell 'aqi'.Q1000>, <Cell 'aqi'.R1000>, <Cell 'aqi'.S1000>, <Cell 'aqi'.T1000>, <Cell 'aqi'.U1000>, <Cell 'aqi'.V1000>, <Cell 'aqi'.W1000>, <Cell 'aqi'.X1000>, <Cell 'aqi'.Y1000>)
# (<Cell 'aqi'.A1001>, <Cell 'aqi'.B1001>, <Cell 'aqi'.C1001>, <Cell 'aqi'.D1001>, <Cell 'aqi'.E1001>, <Cell 'aqi'.F1001>, <Cell 'aqi'.G1001>, <Cell 'aqi'.H1001>, <Cell 'aqi'.I1001>, <Cell 'aqi'.J1001>, <Cell 'aqi'.K1001>, <Cell 'aqi'.L1001>, <Cell 'aqi'.M1001>, <Cell 'aqi'.N1001>, <Cell 'aqi'.O1001>, <Cell 'aqi'.P1001>, <Cell 'aqi'.Q1001>, <Cell 'aqi'.R1001>, <Cell 'aqi'.S1001>, <Cell 'aqi'.T1001>, <Cell 'aqi'.U1001>, <Cell 'aqi'.V1001>, <Cell 'aqi'.W1001>, <Cell 'aqi'.X1001>, <Cell 'aqi'.Y1001>)

# %%
from pprint import pprint
sheet:worksheet = wb.worksheets[0]
type(sheet)
sheets:list = []
column_names:list[str] =[cell.value for cell in list(sheet)[0]]
print(column_names)

for row in list(sheet)[1:]:
    site:dict = {}
    for idx,cell in enumerate(row):        
        #print(column_names[idx], item.value)
        #print(idx,cell)
        site[column_names[idx]] = cell.value
    #print("===========")
    sheets.append(site)
#print(len(sheets))
pprint(sheets)

# %%
from openpyxl import load_workbook, Workbook, worksheet

wb:Workbook = load_workbook('aqi.xlsx')
from pprint import pprint
sheet:worksheet = wb.worksheets[0]
sheets:list = []
column_names:list[str] =[cell.value for cell in list(sheet)[0]]
for row in list(sheet)[1:]:
    site:dict = {column_names[idx]:cell.value for idx,cell in enumerate(row)}    
    sheets.append(site)

pprint(sheets)
# Out:
# [{'aqi': 40,
#   'co': 0.24,
#   'co_8hr': 0.1,
#   'county': '屏東縣',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 22.260899,
#   'longitude': 120.651472,
#   'no': 0.2,
#   'no2': 2.4,
#   'nox': 2.6,
#   'o3': 39.4,
#   'o3_8hr': 43.6,
#   'pm10': 17,
#   'pm10_avg': 27,
#   'pm2.5': 6,
#   'pm2.5_avg': 8.7,
#   'pollutant': None,
#   'siteid': 313,
#   'sitename': '屏東(枋山)',
#   'so2': 0,
#   'so2_avg': 0,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 90,
#   'windspeed': 5.7},
#  {'aqi': 36,
#   'co': 0.33,
#   'co_8hr': 0.3,
#   'county': '花蓮縣',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 23.97709367,
#   'longitude': 121.61575076,
#   'no': 0.8,
#   'no2': 3.8,
#   'nox': 4.6,
#   'o3': 47.7,
#   'o3_8hr': 39.3,
#   'pm10': 26,
#   'pm10_avg': 25,
#   'pm2.5': 12,
#   'pm2.5_avg': 10.8,
#   'pollutant': None,
#   'siteid': 312,
#   'sitename': '花蓮（美崙）',
#   'so2': 0,
#   'so2_avg': 0,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 33,
#   'windspeed': 5},
#  {'aqi': 37,
#   'co': 0.41,
#   'co_8hr': 0.4,
#   'county': '新北市',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 24.94902778,
#   'longitude': 121.38352778,
#   'no': 4.9,
#   'no2': 19.7,
#   'nox': 24.6,
#   'o3': 29.1,
#   'o3_8hr': 23.6,
#   'pm10': 40,
#   'pm10_avg': 30,
#   'pm2.5': 16,
#   'pm2.5_avg': 11.4,
#   'pollutant': None,
#   'siteid': 311,
#   'sitename': '新北(樹林)',
#   'so2': 0.3,
#   'so2_avg': 0,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 141,
#   'windspeed': 0},
#  {'aqi': 57,
#   'co': 0.4,
#   'co_8hr': 0.3,
#   'county': '屏東縣',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 22.35222,
#   'longitude': 120.37722,
#   'no': 0.8,
#   'no2': 12.5,
#   'nox': 13.4,
#   'o3': 39,
#   'o3_8hr': 55.2,
#   'pm10': 86,
#   'pm10_avg': 54,
#   'pm2.5': 17,
#   'pm2.5_avg': 17.8,
#   'pollutant': '細懸浮微粒',
#   'siteid': 204,
#   'sitename': '屏東（琉球）',
#   'so2': 1.4,
#   'so2_avg': 2,
#   'status': '普通',
#   'unit': None,
#   'winddirec': 320,
#   'windspeed': 3.2},
#  {'aqi': 80,
#   'co': 0.39,
#   'co_8hr': 0.3,
#   'county': '臺南市',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 23.17904722,
#   'longitude': 120.24583056,
#   'no': 0.4,
#   'no2': 16.8,
#   'nox': 17.3,
#   'o3': 16.3,
#   'o3_8hr': 37.8,
#   'pm10': 65,
#   'pm10_avg': 80,
#   'pm2.5': 16,
#   'pm2.5_avg': 14.5,
#   'pollutant': '懸浮微粒',
#   'siteid': 203,
#   'sitename': '臺南（麻豆）',
#   'so2': 1.8,
#   'so2_avg': 1,
#   'status': '普通',
#   'unit': None,
#   'winddirec': 12,
#   'windspeed': 3.4},
#  {'aqi': 73,
#   'co': 0.44,
#   'co_8hr': 0.3,
#   'county': '高雄市',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 22.87985556,
#   'longitude': 120.24535,
#   'no': 0.2,
#   'no2': 16.8,
#   'nox': 17,
#   'o3': 20.2,
#   'o3_8hr': 41.4,
#   'pm10': 101,
#   'pm10_avg': 73,
#   'pm2.5': 14,
#   'pm2.5_avg': 9.9,
#   'pollutant': '懸浮微粒',
#   'siteid': 202,
#   'sitename': '高雄（湖內）',
#   'so2': 1.8,
#   'so2_avg': 1,
#   'status': '普通',
#   'unit': None,
#   'winddirec': 318,
#   'windspeed': 1.4},
#  {'aqi': 30,
#   'co': 0.34,
#   'co_8hr': 0.3,
#   'county': '彰化縣',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 23.96117,
#   'longitude': 120.56373,
#   'no': 1.6,
#   'no2': 11,
#   'nox': 12.6,
#   'o3': 26.8,
#   'o3_8hr': 33,
#   'pm10': 22,
#   'pm10_avg': 27,
#   'pm2.5': 9,
#   'pm2.5_avg': 7.8,
#   'pollutant': None,
#   'siteid': 201,
#   'sitename': '彰化（員林）',
#   'so2': 1.1,
#   'so2_avg': 1,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 355,
#   'windspeed': 1.5},
#  {'aqi': 40,
#   'co': 0.25,
#   'co_8hr': 0.2,
#   'county': '彰化縣',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 23.85493056,
#   'longitude': 120.26964167,
#   'no': 0.4,
#   'no2': 6.8,
#   'nox': 7.2,
#   'o3': 37.5,
#   'o3_8hr': 42.1,
#   'pm10': 36,
#   'pm10_avg': 30,
#   'pm2.5': 16,
#   'pm2.5_avg': 12.2,
#   'pollutant': None,
#   'siteid': 85,
#   'sitename': '大城',
#   'so2': 1.5,
#   'so2_avg': 1,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 47,
#   'windspeed': 8.6},
#  {'aqi': 49,
#   'co': 0.2,
#   'co_8hr': 0.2,
#   'county': '新北市',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 25.29681695,
#   'longitude': 121.53656894,
#   'no': 0.1,
#   'no2': 1.6,
#   'nox': 1.7,
#   'o3': 54.8,
#   'o3_8hr': 49.2,
#   'pm10': 55,
#   'pm10_avg': 49,
#   'pm2.5': 18,
#   'pm2.5_avg': 14,
#   'pollutant': None,
#   'siteid': 84,
#   'sitename': '富貴角',
#   'so2': 0.3,
#   'so2_avg': 0,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 51,
#   'windspeed': 9.1},
#  {'aqi': 65,
#   'co': 0.29,
#   'co_8hr': 0.3,
#   'county': '雲林縣',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 23.753506,
#   'longitude': 120.251825,
#   'no': 1.1,
#   'no2': 7.6,
#   'nox': 8.8,
#   'o3': 34,
#   'o3_8hr': 40.3,
#   'pm10': 46,
#   'pm10_avg': 65,
#   'pm2.5': 19,
#   'pm2.5_avg': 13.3,
#   'pollutant': '懸浮微粒',
#   'siteid': 83,
#   'sitename': '麥寮',
#   'so2': 1.5,
#   'so2_avg': 1,
#   'status': '普通',
#   'unit': None,
#   'winddirec': 3,
#   'windspeed': 5.9},
#  {'aqi': 34,
#   'co': 0.31,
#   'co_8hr': 0.2,
#   'county': '臺東縣',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 23.045083,
#   'longitude': 121.161933,
#   'no': 0.3,
#   'no2': 4.2,
#   'nox': 4.5,
#   'o3': 31.7,
#   'o3_8hr': 33,
#   'pm10': 16,
#   'pm10_avg': 34,
#   'pm2.5': 5,
#   'pm2.5_avg': 5.2,
#   'pollutant': None,
#   'siteid': 80,
#   'sitename': '關山',
#   'so2': 0.9,
#   'so2_avg': 1,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 32,
#   'windspeed': 2.3},
#  {'aqi': 37,
#   'co': 0.26,
#   'co_8hr': 0.3,
#   'county': '澎湖縣',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 23.569031,
#   'longitude': 119.566158,
#   'no': 0.8,
#   'no2': 2.7,
#   'nox': 3.5,
#   'o3': 46.3,
#   'o3_8hr': 40.2,
#   'pm10': 21,
#   'pm10_avg': 14,
#   'pm2.5': 8,
#   'pm2.5_avg': 5.7,
#   'pollutant': None,
#   'siteid': 78,
#   'sitename': '馬公',
#   'so2': 1.2,
#   'so2_avg': 1,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 32,
#   'windspeed': 7.3},
#  {'aqi': 46,
#   'co': 0.37,
#   'co_8hr': 0.3,
#   'county': '金門縣',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 24.432133,
#   'longitude': 118.312256,
#   'no': 0.6,
#   'no2': 7.8,
#   'nox': 8.5,
#   'o3': 36.4,
#   'o3_8hr': 50.2,
#   'pm10': 23,
#   'pm10_avg': 21,
#   'pm2.5': 14,
#   'pm2.5_avg': 9.6,
#   'pollutant': None,
#   'siteid': 77,
#   'sitename': '金門',
#   'so2': 1.3,
#   'so2_avg': 0,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 76,
#   'windspeed': 2.7},
#  {'aqi': 43,
#   'co': 0.26,
#   'co_8hr': 0.2,
#   'county': '連江縣',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 26.153736,
#   'longitude': 119.952724,
#   'no': 1,
#   'no2': 3.7,
#   'nox': 4.7,
#   'o3': 53.3,
#   'o3_8hr': 46.4,
#   'pm10': 34,
#   'pm10_avg': 26,
#   'pm2.5': 14,
#   'pm2.5_avg': 10.6,
#   'pollutant': None,
#   'siteid': 75,
#   'sitename': '馬祖',
#   'so2': 0.6,
#   'so2_avg': 0,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 355,
#   'windspeed': 1.2},
#  {'aqi': 46,
#   'co': 0.42,
#   'co_8hr': 0.2,
#   'county': '南投縣',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 23.968842,
#   'longitude': 120.967903,
#   'no': 1.3,
#   'no2': 9.7,
#   'nox': 11,
#   'o3': 30.8,
#   'o3_8hr': 36.2,
#   'pm10': 21,
#   'pm10_avg': 18,
#   'pm2.5': 12,
#   'pm2.5_avg': 14.3,
#   'pollutant': None,
#   'siteid': 72,
#   'sitename': '埔里',
#   'so2': 1.6,
#   'so2_avg': 1,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 321,
#   'windspeed': 0.3},
#  {'aqi': 68,
#   'co': 0.52,
#   'co_8hr': 0.4,
#   'county': '高雄市',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 22.608711,
#   'longitude': 120.312017,
#   'no': 1.5,
#   'no2': 19.2,
#   'nox': 20.7,
#   'o3': 28.5,
#   'o3_8hr': 42.4,
#   'pm10': 122,
#   'pm10_avg': 68,
#   'pm2.5': 21,
#   'pm2.5_avg': 18.4,
#   'pollutant': '懸浮微粒',
#   'siteid': 71,
#   'sitename': '復興',
#   'so2': 1.4,
#   'so2_avg': 1,
#   'status': '普通',
#   'unit': None,
#   'winddirec': 165,
#   'windspeed': 1.5},
#  {'aqi': 35,
#   'co': 0.44,
#   'co_8hr': 0.4,
#   'county': '新北市',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 25.017,
#   'longitude': 121.516306,
#   'no': 2.9,
#   'no2': 13.6,
#   'nox': 16.5,
#   'o3': 37.8,
#   'o3_8hr': 32,
#   'pm10': 40,
#   'pm10_avg': 32,
#   'pm2.5': 12,
#   'pm2.5_avg': 10.7,
#   'pollutant': None,
#   'siteid': 70,
#   'sitename': '永和',
#   'so2': 1.1,
#   'so2_avg': 1,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 82,
#   'windspeed': 2.2},
#  {'aqi': 36,
#   'co': 0.41,
#   'co_8hr': 0.3,
#   'county': '南投縣',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 23.756389,
#   'longitude': 120.677306,
#   'no': 0.5,
#   'no2': 17.4,
#   'nox': 17.9,
#   'o3': 15.3,
#   'o3_8hr': 37.3,
#   'pm10': 32,
#   'pm10_avg': 28,
#   'pm2.5': 11,
#   'pm2.5_avg': 11.1,
#   'pollutant': None,
#   'siteid': 69,
#   'sitename': '竹山',
#   'so2': 0.8,
#   'so2_avg': 0,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 28,
#   'windspeed': 2},
#  {'aqi': 42,
#   'co': 0.78,
#   'co_8hr': 0.7,
#   'county': '桃園市',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 24.953278,
#   'longitude': 121.221667,
#   'no': 15.5,
#   'no2': 24.4,
#   'nox': 39.9,
#   'o3': 23.9,
#   'o3_8hr': 17.7,
#   'pm10': 35,
#   'pm10_avg': 29,
#   'pm2.5': 16,
#   'pm2.5_avg': 12.8,
#   'pollutant': None,
#   'siteid': 68,
#   'sitename': '中壢',
#   'so2': 1,
#   'so2_avg': 0,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 5,
#   'windspeed': 1.3},
#  {'aqi': 52,
#   'co': 0.84,
#   'co_8hr': 1,
#   'county': '新北市',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 25.072611,
#   'longitude': 121.493806,
#   'no': 38.1,
#   'no2': 32.6,
#   'nox': 70.7,
#   'o3': 18.5,
#   'o3_8hr': 12.9,
#   'pm10': 48,
#   'pm10_avg': 37,
#   'pm2.5': 15,
#   'pm2.5_avg': 13.8,
#   'pollutant': '二氧化氮',
#   'siteid': 67,
#   'sitename': '三重',
#   'so2': 0.7,
#   'so2_avg': 0,
#   'status': '普通',
#   'unit': None,
#   'winddirec': '-',
#   'windspeed': '-'},
#  {'aqi': 31,
#   'co': 0.25,
#   'co_8hr': 0.2,
#   'county': '宜蘭縣',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 24.632203,
#   'longitude': 121.792928,
#   'no': 1.2,
#   'no2': 6.7,
#   'nox': 7.9,
#   'o3': 39.2,
#   'o3_8hr': 33.6,
#   'pm10': 34,
#   'pm10_avg': 31,
#   'pm2.5': 12,
#   'pm2.5_avg': 9.4,
#   'pollutant': None,
#   'siteid': 66,
#   'sitename': '冬山',
#   'so2': 0.7,
#   'so2_avg': 0,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 239,
#   'windspeed': 1.2},
#  {'aqi': 31,
#   'co': 0.28,
#   'co_8hr': 0.3,
#   'county': '宜蘭縣',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 24.747917,
#   'longitude': 121.746394,
#   'no': 0.6,
#   'no2': 4.8,
#   'nox': 5.4,
#   'o3': 33.2,
#   'o3_8hr': 33.3,
#   'pm10': 23,
#   'pm10_avg': 20,
#   'pm2.5': 11,
#   'pm2.5_avg': 9.7,
#   'pollutant': None,
#   'siteid': 65,
#   'sitename': '宜蘭',
#   'so2': 0.8,
#   'so2_avg': 1,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 293,
#   'windspeed': 1.1},
#  {'aqi': 39,
#   'co': 0.24,
#   'co_8hr': 0.2,
#   'county': '臺北市',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 25.182722,
#   'longitude': 121.529583,
#   'no': 1,
#   'no2': 1.1,
#   'nox': 2.2,
#   'o3': 49.7,
#   'o3_8hr': 43,
#   'pm10': 28,
#   'pm10_avg': 17,
#   'pm2.5': 7,
#   'pm2.5_avg': 4.7,
#   'pollutant': None,
#   'siteid': 64,
#   'sitename': '陽明',
#   'so2': 0.9,
#   'so2_avg': 0,
#   'status': '良好',
#   'unit': None,
#   'winddirec': None,
#   'windspeed': None},
#  {'aqi': 34,
#   'co': 0.25,
#   'co_8hr': 0.3,
#   'county': '花蓮縣',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 23.971306,
#   'longitude': 121.599769,
#   'no': 0.4,
#   'no2': 3.9,
#   'nox': 4.3,
#   'o3': 45.4,
#   'o3_8hr': 37.3,
#   'pm10': 34,
#   'pm10_avg': 31,
#   'pm2.5': 10,
#   'pm2.5_avg': 8.2,
#   'pollutant': None,
#   'siteid': 63,
#   'sitename': '花蓮',
#   'so2': 1.6,
#   'so2_avg': 1,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 72,
#   'windspeed': 4.4},
#  {'aqi': 34,
#   'co': 0.39,
#   'co_8hr': 0.3,
#   'county': '臺東縣',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 22.755358,
#   'longitude': 121.15045,
#   'no': 1.4,
#   'no2': 6.3,
#   'nox': 7.8,
#   'o3': 29,
#   'o3_8hr': 37,
#   'pm10': 12,
#   'pm10_avg': 21,
#   'pm2.5': 5,
#   'pm2.5_avg': 7.2,
#   'pollutant': None,
#   'siteid': 62,
#   'sitename': '臺東',
#   'so2': 1,
#   'so2_avg': 1,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 326,
#   'windspeed': 1.6},
#  {'aqi': 28,
#   'co': 0.29,
#   'co_8hr': 0.2,
#   'county': '屏東縣',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 21.958069,
#   'longitude': 120.788928,
#   'no': 0.6,
#   'no2': 2.7,
#   'nox': 3.4,
#   'o3': None,
#   'o3_8hr': None,
#   'pm10': 20,
#   'pm10_avg': 17,
#   'pm2.5': 7,
#   'pm2.5_avg': 8.5,
#   'pollutant': None,
#   'siteid': 61,
#   'sitename': '恆春',
#   'so2': 0.7,
#   'so2_avg': 0,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 27,
#   'windspeed': 10.2},
#  {'aqi': 53,
#   'co': 0.35,
#   'co_8hr': 0.2,
#   'county': '屏東縣',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 22.523108,
#   'longitude': 120.561175,
#   'no': 1.5,
#   'no2': 11,
#   'nox': 12.5,
#   'o3': 34.8,
#   'o3_8hr': 50.6,
#   'pm10': 63,
#   'pm10_avg': 34,
#   'pm2.5': 22,
#   'pm2.5_avg': 16.3,
#   'pollutant': '細懸浮微粒',
#   'siteid': 60,
#   'sitename': '潮州',
#   'so2': 1.5,
#   'so2_avg': 0,
#   'status': '普通',
#   'unit': None,
#   'winddirec': 285,
#   'windspeed': 2.1},
#  {'aqi': 48,
#   'co': 0.42,
#   'co_8hr': 0.2,
#   'county': '屏東縣',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 22.673081,
#   'longitude': 120.488033,
#   'no': 0.5,
#   'no2': 13.1,
#   'nox': 13.6,
#   'o3': 36.7,
#   'o3_8hr': 46.5,
#   'pm10': 116,
#   'pm10_avg': 48,
#   'pm2.5': 21,
#   'pm2.5_avg': 13.7,
#   'pollutant': None,
#   'siteid': 59,
#   'sitename': '屏東',
#   'so2': 1.7,
#   'so2_avg': 1,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 256,
#   'windspeed': 1.8},
#  {'aqi': 63,
#   'co': 0.53,
#   'co_8hr': 0.3,
#   'county': '高雄市',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 22.565833,
#   'longitude': 120.337736,
#   'no': 0.7,
#   'no2': 22.4,
#   'nox': 23.1,
#   'o3': 29.4,
#   'o3_8hr': 43.8,
#   'pm10': 113,
#   'pm10_avg': 63,
#   'pm2.5': 20,
#   'pm2.5_avg': 14.9,
#   'pollutant': '懸浮微粒',
#   'siteid': 58,
#   'sitename': '小港',
#   'so2': 1.3,
#   'so2_avg': 1,
#   'status': '普通',
#   'unit': None,
#   'winddirec': 331,
#   'windspeed': 1.3},
#  {'aqi': 74,
#   'co': 0.53,
#   'co_8hr': 0.4,
#   'county': '高雄市',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 22.6044507,
#   'longitude': 120.30833356,
#   'no': 2.5,
#   'no2': 19.5,
#   'nox': 22,
#   'o3': 28.3,
#   'o3_8hr': 43.3,
#   'pm10': 139,
#   'pm10_avg': 74,
#   'pm2.5': 23,
#   'pm2.5_avg': 18,
#   'pollutant': '懸浮微粒',
#   'siteid': 57,
#   'sitename': '前鎮',
#   'so2': 1.8,
#   'so2_avg': 1,
#   'status': '普通',
#   'unit': None,
#   'winddirec': 3,
#   'windspeed': 3.2},
#  {'aqi': 79,
#   'co': 0.46,
#   'co_8hr': 0.3,
#   'county': '高雄市',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 22.63390278,
#   'longitude': 120.28676111,
#   'no': 0.8,
#   'no2': 18.3,
#   'nox': 19.2,
#   'o3': 27.4,
#   'o3_8hr': 44.4,
#   'pm10': 130,
#   'pm10_avg': 79,
#   'pm2.5': 15,
#   'pm2.5_avg': 14.3,
#   'pollutant': '懸浮微粒',
#   'siteid': 56,
#   'sitename': '前金',
#   'so2': 1.4,
#   'so2_avg': 0,
#   'status': '普通',
#   'unit': None,
#   'winddirec': 354,
#   'windspeed': 4.2},
#  {'aqi': 82,
#   'co': 0.46,
#   'co_8hr': 0.3,
#   'county': '高雄市',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 22.674861,
#   'longitude': 120.292917,
#   'no': 0.7,
#   'no2': 16.7,
#   'nox': 17.5,
#   'o3': 28.2,
#   'o3_8hr': 46.3,
#   'pm10': 163,
#   'pm10_avg': 82,
#   'pm2.5': 23,
#   'pm2.5_avg': 16.7,
#   'pollutant': '懸浮微粒',
#   'siteid': 54,
#   'sitename': '左營',
#   'so2': 1.5,
#   'so2_avg': 1,
#   'status': '普通',
#   'unit': None,
#   'winddirec': 7,
#   'windspeed': 3},
#  {'aqi': 90,
#   'co': 0.45,
#   'co_8hr': 0.3,
#   'county': '高雄市',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 22.733667,
#   'longitude': 120.328289,
#   'no': 0.4,
#   'no2': 16.6,
#   'nox': 17.1,
#   'o3': 26.7,
#   'o3_8hr': 45.4,
#   'pm10': 182,
#   'pm10_avg': 90,
#   'pm2.5': 20,
#   'pm2.5_avg': 14.7,
#   'pollutant': '懸浮微粒',
#   'siteid': 53,
#   'sitename': '楠梓',
#   'so2': 1.8,
#   'so2_avg': 1,
#   'status': '普通',
#   'unit': None,
#   'winddirec': 340,
#   'windspeed': 2.3},
#  {'aqi': 59,
#   'co': 0.51,
#   'co_8hr': 0.3,
#   'county': '高雄市',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 22.4795,
#   'longitude': 120.41175,
#   'no': 0,
#   'no2': 23.2,
#   'nox': 23.2,
#   'o3': 28.4,
#   'o3_8hr': 47.3,
#   'pm10': 84,
#   'pm10_avg': 59,
#   'pm2.5': 17,
#   'pm2.5_avg': 16.8,
#   'pollutant': '懸浮微粒',
#   'siteid': 52,
#   'sitename': '林園',
#   'so2': 1.8,
#   'so2_avg': 1,
#   'status': '普通',
#   'unit': None,
#   'winddirec': 315,
#   'windspeed': 1},
#  {'aqi': 52,
#   'co': 0.46,
#   'co_8hr': 0.2,
#   'county': '高雄市',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 22.56413611,
#   'longitude': 120.425311,
#   'no': 0.9,
#   'no2': 23.2,
#   'nox': 24.2,
#   'o3': 24.7,
#   'o3_8hr': 41.6,
#   'pm10': 57,
#   'pm10_avg': 33,
#   'pm2.5': 18,
#   'pm2.5_avg': 16,
#   'pollutant': '細懸浮微粒',
#   'siteid': 51,
#   'sitename': '大寮',
#   'so2': 2.1,
#   'so2_avg': 2,
#   'status': '普通',
#   'unit': None,
#   'winddirec': 318,
#   'windspeed': 1.8},
#  {'aqi': 71,
#   'co': 0.71,
#   'co_8hr': 0.4,
#   'county': '高雄市',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 22.628126,
#   'longitude': 120.357422,
#   'no': 3,
#   'no2': 21.4,
#   'nox': 24.5,
#   'o3': 25.2,
#   'o3_8hr': 41.1,
#   'pm10': 164,
#   'pm10_avg': 71,
#   'pm2.5': 26,
#   'pm2.5_avg': 19.3,
#   'pollutant': '懸浮微粒',
#   'siteid': 50,
#   'sitename': '鳳山',
#   'so2': 1.3,
#   'so2_avg': 1,
#   'status': '普通',
#   'unit': None,
#   'winddirec': 252,
#   'windspeed': 1.3},
#  {'aqi': 64,
#   'co': 0.48,
#   'co_8hr': 0.3,
#   'county': '高雄市',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 22.689056,
#   'longitude': 120.332631,
#   'no': 1.1,
#   'no2': 17.9,
#   'nox': 19,
#   'o3': 25.4,
#   'o3_8hr': 43.7,
#   'pm10': 136,
#   'pm10_avg': 64,
#   'pm2.5': 25,
#   'pm2.5_avg': 17.6,
#   'pollutant': '懸浮微粒',
#   'siteid': 49,
#   'sitename': '仁武',
#   'so2': 1.5,
#   'so2_avg': 1,
#   'status': '普通',
#   'unit': None,
#   'winddirec': 342,
#   'windspeed': 2.8},
#  {'aqi': 83,
#   'co': 0.48,
#   'co_8hr': 0.3,
#   'county': '高雄市',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 22.757506,
#   'longitude': 120.305689,
#   'no': 1.5,
#   'no2': 20.2,
#   'nox': 21.7,
#   'o3': 22.9,
#   'o3_8hr': 44.1,
#   'pm10': 153,
#   'pm10_avg': 83,
#   'pm2.5': 24,
#   'pm2.5_avg': 15.7,
#   'pollutant': '懸浮微粒',
#   'siteid': 48,
#   'sitename': '橋頭',
#   'so2': 1.7,
#   'so2_avg': 1,
#   'status': '普通',
#   'unit': None,
#   'winddirec': 10,
#   'windspeed': 3.2},
#  {'aqi': 54,
#   'co': 0.39,
#   'co_8hr': 0.2,
#   'county': '高雄市',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 22.883583,
#   'longitude': 120.530542,
#   'no': 0.7,
#   'no2': 9.1,
#   'nox': 9.8,
#   'o3': 36.2,
#   'o3_8hr': 44.8,
#   'pm10': 123,
#   'pm10_avg': 54,
#   'pm2.5': 21,
#   'pm2.5_avg': 12.1,
#   'pollutant': '懸浮微粒',
#   'siteid': 47,
#   'sitename': '美濃',
#   'so2': 1.6,
#   'so2_avg': 1,
#   'status': '普通',
#   'unit': None,
#   'winddirec': 267,
#   'windspeed': 1.2},
#  {'aqi': 75,
#   'co': 0.45,
#   'co_8hr': 0.3,
#   'county': '臺南市',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 22.98928311,
#   'longitude': 120.21947897,
#   'no': 0.6,
#   'no2': 17.2,
#   'nox': 17.8,
#   'o3': 19.6,
#   'o3_8hr': 42.1,
#   'pm10': 73,
#   'pm10_avg': 75,
#   'pm2.5': 21,
#   'pm2.5_avg': 14.5,
#   'pollutant': '懸浮微粒',
#   'siteid': 46,
#   'sitename': '臺南',
#   'so2': 2,
#   'so2_avg': 1,
#   'status': '普通',
#   'unit': None,
#   'winddirec': 2,
#   'windspeed': 4.2},
#  {'aqi': 75,
#   'co': 0.43,
#   'co_8hr': 0.3,
#   'county': '臺南市',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 23.048197,
#   'longitude': 120.2175,
#   'no': 0.4,
#   'no2': 13.7,
#   'nox': 14.2,
#   'o3': 20.9,
#   'o3_8hr': 42.6,
#   'pm10': 63,
#   'pm10_avg': 75,
#   'pm2.5': 13,
#   'pm2.5_avg': 14.7,
#   'pollutant': '懸浮微粒',
#   'siteid': 45,
#   'sitename': '安南',
#   'so2': 1.5,
#   'so2_avg': 0,
#   'status': '普通',
#   'unit': None,
#   'winddirec': 320,
#   'windspeed': 3},
#  {'aqi': 92,
#   'co': 0.4,
#   'co_8hr': 0.2,
#   'county': '臺南市',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 23.11337642,
#   'longitude': 120.29740529,
#   'no': 0.7,
#   'no2': 13.6,
#   'nox': 14.4,
#   'o3': 19.8,
#   'o3_8hr': 42.1,
#   'pm10': 60,
#   'pm10_avg': 92,
#   'pm2.5': 16,
#   'pm2.5_avg': 13.2,
#   'pollutant': '懸浮微粒',
#   'siteid': 44,
#   'sitename': '善化',
#   'so2': 1.7,
#   'so2_avg': 1,
#   'status': '普通',
#   'unit': None,
#   'winddirec': 355,
#   'windspeed': 3.9},
#  {'aqi': 105,
#   'co': 0.45,
#   'co_8hr': 0.3,
#   'county': '臺南市',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 23.305633,
#   'longitude': 120.31725,
#   'no': 0.2,
#   'no2': 16.5,
#   'nox': 16.8,
#   'o3': 17.3,
#   'o3_8hr': 37.7,
#   'pm10': 63,
#   'pm10_avg': 113,
#   'pm2.5': 16,
#   'pm2.5_avg': 16.6,
#   'pollutant': '懸浮微粒',
#   'siteid': 43,
#   'sitename': '新營',
#   'so2': 1.9,
#   'so2_avg': 1,
#   'status': '對敏感族群不健康',
#   'unit': None,
#   'winddirec': 14,
#   'windspeed': 3.4},
#  {'aqi': 63,
#   'co': 0.47,
#   'co_8hr': 0.3,
#   'county': '嘉義市',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 23.46477865,
#   'longitude': 120.44125148,
#   'no': 1.6,
#   'no2': 17.2,
#   'nox': 18.8,
#   'o3': 15.4,
#   'o3_8hr': 37.4,
#   'pm10': 26,
#   'pm10_avg': 63,
#   'pm2.5': 16,
#   'pm2.5_avg': 14.2,
#   'pollutant': '懸浮微粒',
#   'siteid': 42,
#   'sitename': '嘉義',
#   'so2': 10.5,
#   'so2_avg': 2,
#   'status': '普通',
#   'unit': None,
#   'winddirec': 6,
#   'windspeed': 2.7},
#  {'aqi': 39,
#   'co': 0.28,
#   'co_8hr': 0.3,
#   'county': '雲林縣',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 23.702175,
#   'longitude': 120.19933333,
#   'no': 0.5,
#   'no2': 6.2,
#   'nox': 6.8,
#   'o3': 35.9,
#   'o3_8hr': 41,
#   'pm10': 49,
#   'pm10_avg': 39,
#   'pm2.5': 10,
#   'pm2.5_avg': 8.9,
#   'pollutant': None,
#   'siteid': 41,
#   'sitename': '臺西',
#   'so2': 1.1,
#   'so2_avg': 1,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 25,
#   'windspeed': 7.4},
#  {'aqi': 72,
#   'co': 0.31,
#   'co_8hr': 0.3,
#   'county': '嘉義縣',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 23.46538,
#   'longitude': 120.2478,
#   'no': 1.9,
#   'no2': 11.4,
#   'nox': 13.3,
#   'o3': 25.1,
#   'o3_8hr': 38.8,
#   'pm10': 56,
#   'pm10_avg': 72,
#   'pm2.5': 9,
#   'pm2.5_avg': 9.6,
#   'pollutant': '懸浮微粒',
#   'siteid': 40,
#   'sitename': '朴子',
#   'so2': 2.3,
#   'so2_avg': 1,
#   'status': '普通',
#   'unit': None,
#   'winddirec': 352,
#   'windspeed': 2.4},
#  {'aqi': 104,
#   'co': 0.32,
#   'co_8hr': 0.3,
#   'county': '嘉義縣',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 23.554839,
#   'longitude': 120.345531,
#   'no': 0.4,
#   'no2': 12.9,
#   'nox': 13.3,
#   'o3': 25.4,
#   'o3_8hr': 38.3,
#   'pm10': 40,
#   'pm10_avg': 109,
#   'pm2.5': 12,
#   'pm2.5_avg': 15.3,
#   'pollutant': '懸浮微粒',
#   'siteid': 39,
#   'sitename': '新港',
#   'so2': 1.9,
#   'so2_avg': 1,
#   'status': '對敏感族群不健康',
#   'unit': None,
#   'winddirec': 5,
#   'windspeed': 3.4},
#  {'aqi': 124,
#   'co': 0.34,
#   'co_8hr': 0.3,
#   'county': '雲林縣',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 23.757547,
#   'longitude': 120.348742,
#   'no': 0.7,
#   'no2': 11.3,
#   'nox': 12.1,
#   'o3': 26.9,
#   'o3_8hr': 33.9,
#   'pm10': 135,
#   'pm10_avg': 173,
#   'pm2.5': 14,
#   'pm2.5_avg': 17,
#   'pollutant': '懸浮微粒',
#   'siteid': 38,
#   'sitename': '崙背',
#   'so2': 1.6,
#   'so2_avg': 1,
#   'status': '對敏感族群不健康',
#   'unit': None,
#   'winddirec': 2,
#   'windspeed': 2.4},
#  {'aqi': 49,
#   'co': 0.36,
#   'co_8hr': 0.3,
#   'county': '雲林縣',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 23.711853,
#   'longitude': 120.544994,
#   'no': 1,
#   'no2': 12.2,
#   'nox': 13.2,
#   'o3': 22.6,
#   'o3_8hr': 38.8,
#   'pm10': 21,
#   'pm10_avg': 49,
#   'pm2.5': 10,
#   'pm2.5_avg': 10.8,
#   'pollutant': None,
#   'siteid': 37,
#   'sitename': '斗六',
#   'so2': 1,
#   'so2_avg': 1,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 344,
#   'windspeed': 1.8},
#  {'aqi': 31,
#   'co': 0.39,
#   'co_8hr': 0.3,
#   'county': '南投縣',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 23.913,
#   'longitude': 120.685306,
#   'no': 1.2,
#   'no2': 15.5,
#   'nox': 16.8,
#   'o3': 19.7,
#   'o3_8hr': 33.4,
#   'pm10': 21,
#   'pm10_avg': 26,
#   'pm2.5': 6,
#   'pm2.5_avg': 9.1,
#   'pollutant': None,
#   'siteid': 36,
#   'sitename': '南投',
#   'so2': 1.1,
#   'so2_avg': 1,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 340,
#   'windspeed': 1.5},
#  {'aqi': 39,
#   'co': 0.29,
#   'co_8hr': 0.3,
#   'county': '彰化縣',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 23.925175,
#   'longitude': 120.409653,
#   'no': 0.3,
#   'no2': 9.1,
#   'nox': 9.5,
#   'o3': 34.8,
#   'o3_8hr': 37.4,
#   'pm10': 39,
#   'pm10_avg': 39,
#   'pm2.5': 10,
#   'pm2.5_avg': 7.8,
#   'pollutant': None,
#   'siteid': 35,
#   'sitename': '二林',
#   'so2': 1.1,
#   'so2_avg': 1,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 26,
#   'windspeed': 5.6},
#  {'aqi': 34,
#   'co': 0.28,
#   'co_8hr': 0.3,
#   'county': '彰化縣',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 24.131672,
#   'longitude': 120.469061,
#   'no': 0.5,
#   'no2': 12.3,
#   'nox': 12.8,
#   'o3': 32.8,
#   'o3_8hr': 33.6,
#   'pm10': 31,
#   'pm10_avg': 29,
#   'pm2.5': 15,
#   'pm2.5_avg': 10.5,
#   'pollutant': None,
#   'siteid': 34,
#   'sitename': '線西',
#   'so2': 1.8,
#   'so2_avg': 1,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 35,
#   'windspeed': 8},
#  {'aqi': 26,
#   'co': 0.33,
#   'co_8hr': 0.3,
#   'county': '彰化縣',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 24.066,
#   'longitude': 120.541519,
#   'no': 1.1,
#   'no2': 13.2,
#   'nox': 14.3,
#   'o3': 27,
#   'o3_8hr': 28.4,
#   'pm10': 23,
#   'pm10_avg': 22,
#   'pm2.5': 8,
#   'pm2.5_avg': 7.8,
#   'pollutant': None,
#   'siteid': 33,
#   'sitename': '彰化',
#   'so2': 0.6,
#   'so2_avg': 0,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 23,
#   'windspeed': 2.4},
#  {'aqi': 29,
#   'co': 0.27,
#   'co_8hr': 0.3,
#   'county': '臺中市',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 24.162197,
#   'longitude': 120.616917,
#   'no': 1.2,
#   'no2': 7.3,
#   'nox': 8.6,
#   'o3': 33.3,
#   'o3_8hr': 31.9,
#   'pm10': 21,
#   'pm10_avg': 26,
#   'pm2.5': 8,
#   'pm2.5_avg': 7.1,
#   'pollutant': None,
#   'siteid': 32,
#   'sitename': '西屯',
#   'so2': 1,
#   'so2_avg': 0,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 0,
#   'windspeed': 4.7},
#  {'aqi': 27,
#   'co': 0.36,
#   'co_8hr': 0.3,
#   'county': '臺中市',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 24.151958,
#   'longitude': 120.641092,
#   'no': 1.2,
#   'no2': 10.9,
#   'nox': 12.1,
#   'o3': 26.6,
#   'o3_8hr': 29.1,
#   'pm10': 16,
#   'pm10_avg': 19,
#   'pm2.5': 7,
#   'pm2.5_avg': 6.7,
#   'pollutant': None,
#   'siteid': 31,
#   'sitename': '忠明',
#   'so2': 1.5,
#   'so2_avg': 1,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 329,
#   'windspeed': 1.8},
#  {'aqi': 28,
#   'co': 0.39,
#   'co_8hr': 0.4,
#   'county': '臺中市',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 24.09961111,
#   'longitude': 120.67844444,
#   'no': 1.6,
#   'no2': 10.8,
#   'nox': 12.5,
#   'o3': 22.7,
#   'o3_8hr': 30.4,
#   'pm10': 20,
#   'pm10_avg': 19,
#   'pm2.5': 8,
#   'pm2.5_avg': 8.2,
#   'pollutant': None,
#   'siteid': 30,
#   'sitename': '大里',
#   'so2': 1.3,
#   'so2_avg': 1,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 8,
#   'windspeed': 2.1},
#  {'aqi': 26,
#   'co': 0.27,
#   'co_8hr': 0.3,
#   'county': '臺中市',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 24.225628,
#   'longitude': 120.568794,
#   'no': 0.7,
#   'no2': 6.3,
#   'nox': 7,
#   'o3': 13,
#   'o3_8hr': 24.1,
#   'pm10': 26,
#   'pm10_avg': 22,
#   'pm2.5': 11,
#   'pm2.5_avg': 8.1,
#   'pollutant': None,
#   'siteid': 29,
#   'sitename': '沙鹿',
#   'so2': 0.9,
#   'so2_avg': 0,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 9,
#   'windspeed': 5.4},
#  {'aqi': 30,
#   'co': 0.29,
#   'co_8hr': 0.3,
#   'county': '臺中市',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 24.25699731,
#   'longitude': 120.74252414,
#   'no': 0.3,
#   'no2': 5.8,
#   'nox': 6.1,
#   'o3': 27.4,
#   'o3_8hr': 32,
#   'pm10': 11,
#   'pm10_avg': 15,
#   'pm2.5': 10,
#   'pm2.5_avg': 8.7,
#   'pollutant': None,
#   'siteid': 28,
#   'sitename': '豐原',
#   'so2': 0.8,
#   'so2_avg': 1,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 33,
#   'windspeed': 3.3},
#  {'aqi': 30,
#   'co': 0.24,
#   'co_8hr': 0.3,
#   'county': '苗栗縣',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 24.38248443,
#   'longitude': 120.75956754,
#   'no': 0.9,
#   'no2': 3.2,
#   'nox': 4.2,
#   'o3': 40,
#   'o3_8hr': 32.9,
#   'pm10': 25,
#   'pm10_avg': 13,
#   'pm2.5': 9,
#   'pm2.5_avg': 6.5,
#   'pollutant': None,
#   'siteid': 27,
#   'sitename': '三義',
#   'so2': 0.9,
#   'so2_avg': 0,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 16,
#   'windspeed': 7},
#  {'aqi': 30,
#   'co': 0.27,
#   'co_8hr': 0.3,
#   'county': '苗栗縣',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 24.56499183,
#   'longitude': 120.82011468,
#   'no': 1,
#   'no2': 7.7,
#   'nox': 8.7,
#   'o3': 39.6,
#   'o3_8hr': 32.4,
#   'pm10': 27,
#   'pm10_avg': 20,
#   'pm2.5': 14,
#   'pm2.5_avg': 8.5,
#   'pollutant': None,
#   'siteid': 26,
#   'sitename': '苗栗',
#   'so2': 1.6,
#   'so2_avg': 1,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 8,
#   'windspeed': 3.8},
#  {'aqi': 31,
#   'co': 0.32,
#   'co_8hr': 0.3,
#   'county': '苗栗縣',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 24.69690679,
#   'longitude': 120.89869286,
#   'no': 1.1,
#   'no2': 10.5,
#   'nox': 11.6,
#   'o3': 40.8,
#   'o3_8hr': 31.1,
#   'pm10': 34,
#   'pm10_avg': 21,
#   'pm2.5': 11,
#   'pm2.5_avg': 9.5,
#   'pollutant': None,
#   'siteid': 25,
#   'sitename': '頭份',
#   'so2': 1.5,
#   'so2_avg': 1,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 45,
#   'windspeed': 2.3},
#  {'aqi': 28,
#   'co': 0.33,
#   'co_8hr': 0.3,
#   'county': '新竹市',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 24.8056356,
#   'longitude': 120.97236752,
#   'no': 0.4,
#   'no2': 10,
#   'nox': 10.4,
#   'o3': 39.2,
#   'o3_8hr': 30.4,
#   'pm10': 34,
#   'pm10_avg': 24,
#   'pm2.5': 18,
#   'pm2.5_avg': 7.4,
#   'pollutant': None,
#   'siteid': 24,
#   'sitename': '新竹',
#   'so2': 1.6,
#   'so2_avg': 1,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 39,
#   'windspeed': 2.7},
#  {'aqi': 32,
#   'co': 0.24,
#   'co_8hr': 0.2,
#   'county': '新竹縣',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 24.74091408,
#   'longitude': 121.08895493,
#   'no': 0.2,
#   'no2': 5.5,
#   'nox': 5.7,
#   'o3': 43.8,
#   'o3_8hr': 35.1,
#   'pm10': 31,
#   'pm10_avg': 19,
#   'pm2.5': 11,
#   'pm2.5_avg': 6.5,
#   'pollutant': None,
#   'siteid': 23,
#   'sitename': '竹東',
#   'so2': 0.5,
#   'so2_avg': 0,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 45,
#   'windspeed': 3.3},
#  {'aqi': 32,
#   'co': 0.26,
#   'co_8hr': 0.3,
#   'county': '新竹縣',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 24.90009696,
#   'longitude': 121.03886894,
#   'no': 0.3,
#   'no2': 4.5,
#   'nox': 4.9,
#   'o3': 45.1,
#   'o3_8hr': 35,
#   'pm10': 30,
#   'pm10_avg': 24,
#   'pm2.5': 11,
#   'pm2.5_avg': 8.2,
#   'pollutant': None,
#   'siteid': 22,
#   'sitename': '湖口',
#   'so2': 2.4,
#   'so2_avg': 1,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 49,
#   'windspeed': 5.3},
#  {'aqi': 31,
#   'co': 0.27,
#   'co_8hr': 0.3,
#   'county': '桃園市',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 24.86400048,
#   'longitude': 121.21645772,
#   'no': 0.8,
#   'no2': 7.4,
#   'nox': 8.2,
#   'o3': 41.9,
#   'o3_8hr': 33.4,
#   'pm10': 37,
#   'pm10_avg': 26,
#   'pm2.5': 11,
#   'pm2.5_avg': 9.2,
#   'pollutant': None,
#   'siteid': 21,
#   'sitename': '龍潭',
#   'so2': 1.4,
#   'so2_avg': 1,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 62,
#   'windspeed': 6.4},
#  {'aqi': 35,
#   'co': 0.41,
#   'co_8hr': 0.4,
#   'county': '桃園市',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 24.952786,
#   'longitude': 121.203986,
#   'no': 1.5,
#   'no2': 13.3,
#   'nox': 14.8,
#   'o3': 39.4,
#   'o3_8hr': 29.9,
#   'pm10': 29,
#   'pm10_avg': 25,
#   'pm2.5': 15,
#   'pm2.5_avg': 10.7,
#   'pollutant': None,
#   'siteid': 20,
#   'sitename': '平鎮',
#   'so2': 1.2,
#   'so2_avg': 0,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 79,
#   'windspeed': 3.5},
#  {'aqi': 43,
#   'co': 0.24,
#   'co_8hr': 0.2,
#   'county': '桃園市',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 25.03556747,
#   'longitude': 121.08283092,
#   'no': 0.1,
#   'no2': 7.3,
#   'nox': 7.4,
#   'o3': 44.5,
#   'o3_8hr': 36.6,
#   'pm10': 39,
#   'pm10_avg': 41,
#   'pm2.5': 17,
#   'pm2.5_avg': 13.1,
#   'pollutant': None,
#   'siteid': 19,
#   'sitename': '觀音',
#   'so2': 1.8,
#   'so2_avg': 0,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 86,
#   'windspeed': 6.5},
#  {'aqi': 46,
#   'co': 0.27,
#   'co_8hr': 0.3,
#   'county': '桃園市',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 25.06100357,
#   'longitude': 121.20251473,
#   'no': 0.9,
#   'no2': 12.2,
#   'nox': 13.2,
#   'o3': 41.4,
#   'o3_8hr': 34.4,
#   'pm10': 42,
#   'pm10_avg': 34,
#   'pm2.5': 16,
#   'pm2.5_avg': 14.3,
#   'pollutant': None,
#   'siteid': 18,
#   'sitename': '大園',
#   'so2': 1.3,
#   'so2_avg': 1,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 64,
#   'windspeed': 4.4},
#  {'aqi': 27,
#   'co': 0.35,
#   'co_8hr': 0.4,
#   'county': '桃園市',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 24.9947107,
#   'longitude': 121.30500531,
#   'no': 1.2,
#   'no2': 10,
#   'nox': 11.3,
#   'o3': 41.1,
#   'o3_8hr': 29,
#   'pm10': 32,
#   'pm10_avg': 27,
#   'pm2.5': 10,
#   'pm2.5_avg': 8.2,
#   'pollutant': None,
#   'siteid': 17,
#   'sitename': '桃園',
#   'so2': 0.8,
#   'so2_avg': 0,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 51,
#   'windspeed': 3.7},
#  {'aqi': 48,
#   'co': 0.58,
#   'co_8hr': 0.6,
#   'county': '臺北市',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 25.06331455,
#   'longitude': 121.51342074,
#   'no': 15.1,
#   'no2': 26.5,
#   'nox': 41.6,
#   'o3': 26.9,
#   'o3_8hr': 21.6,
#   'pm10': 41,
#   'pm10_avg': 32,
#   'pm2.5': 17,
#   'pm2.5_avg': 14.8,
#   'pollutant': None,
#   'siteid': 16,
#   'sitename': '大同',
#   'so2': 0.8,
#   'so2_avg': 0,
#   'status': '良好',
#   'unit': None,
#   'winddirec': '-',
#   'windspeed': '-'},
#  {'aqi': 46,
#   'co': 0.28,
#   'co_8hr': 0.3,
#   'county': '臺北市',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 25.05,
#   'longitude': 121.578611,
#   'no': 1.9,
#   'no2': 13.2,
#   'nox': 15.2,
#   'o3': 37.6,
#   'o3_8hr': 30.8,
#   'pm10': 44,
#   'pm10_avg': 36,
#   'pm2.5': 16,
#   'pm2.5_avg': 14.1,
#   'pollutant': None,
#   'siteid': 15,
#   'sitename': '松山',
#   'so2': 1.3,
#   'so2_avg': 1,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 18,
#   'windspeed': 2.1},
#  {'aqi': 36,
#   'co': 0.35,
#   'co_8hr': 0.3,
#   'county': '臺北市',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 25.020608,
#   'longitude': 121.529556,
#   'no': 0.6,
#   'no2': 13.2,
#   'nox': 13.8,
#   'o3': 37.1,
#   'o3_8hr': 31.4,
#   'pm10': 40,
#   'pm10_avg': 31,
#   'pm2.5': 13,
#   'pm2.5_avg': 11.2,
#   'pollutant': None,
#   'siteid': 14,
#   'sitename': '古亭',
#   'so2': 1.4,
#   'so2_avg': 0,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 67,
#   'windspeed': 1.8},
#  {'aqi': 39,
#   'co': 0.34,
#   'co_8hr': 0.3,
#   'county': '臺北市',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 25.046503,
#   'longitude': 121.507972,
#   'no': 2.2,
#   'no2': 16.8,
#   'nox': 19.1,
#   'o3': 32.1,
#   'o3_8hr': 22.5,
#   'pm10': 37,
#   'pm10_avg': 32,
#   'pm2.5': 16,
#   'pm2.5_avg': 11.9,
#   'pollutant': None,
#   'siteid': 13,
#   'sitename': '萬華',
#   'so2': 1.6,
#   'so2_avg': 1,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 94,
#   'windspeed': 2.9},
#  {'aqi': 45,
#   'co': 0.42,
#   'co_8hr': 0.4,
#   'county': '臺北市',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 25.062361,
#   'longitude': 121.526528,
#   'no': 2.8,
#   'no2': 17.3,
#   'nox': 20.1,
#   'o3': 34.1,
#   'o3_8hr': 27,
#   'pm10': 42,
#   'pm10_avg': 32,
#   'pm2.5': 16,
#   'pm2.5_avg': 14,
#   'pollutant': None,
#   'siteid': 12,
#   'sitename': '中山',
#   'so2': 0.9,
#   'so2_avg': 0,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 62,
#   'windspeed': 2},
#  {'aqi': 36,
#   'co': 0.24,
#   'co_8hr': 0.2,
#   'county': '臺北市',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 25.10334003,
#   'longitude': 121.51666356,
#   'no': 0.6,
#   'no2': 5.7,
#   'nox': 6.3,
#   'o3': 47.6,
#   'o3_8hr': 39.4,
#   'pm10': 30,
#   'pm10_avg': 27,
#   'pm2.5': 19,
#   'pm2.5_avg': 10.1,
#   'pollutant': None,
#   'siteid': 11,
#   'sitename': '士林',
#   'so2': 0.8,
#   'so2_avg': 0,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 49,
#   'windspeed': 2.3},
#  {'aqi': 36,
#   'co': 0.25,
#   'co_8hr': 0.2,
#   'county': '新北市',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 25.1645,
#   'longitude': 121.449239,
#   'no': 0.9,
#   'no2': 3.3,
#   'nox': 4.3,
#   'o3': 48,
#   'o3_8hr': 39.8,
#   'pm10': 40,
#   'pm10_avg': 28,
#   'pm2.5': 12,
#   'pm2.5_avg': 10.6,
#   'pollutant': None,
#   'siteid': 10,
#   'sitename': '淡水',
#   'so2': 1.4,
#   'so2_avg': 1,
#   'status': '良好',
#   'unit': None,
#   'winddirec': None,
#   'windspeed': None},
#  {'aqi': 31,
#   'co': 0.26,
#   'co_8hr': 0.2,
#   'county': '新北市',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 25.07798949,
#   'longitude': 121.36548982,
#   'no': 1.3,
#   'no2': 7.8,
#   'nox': 9.2,
#   'o3': 40,
#   'o3_8hr': 29.2,
#   'pm10': 32,
#   'pm10_avg': 29,
#   'pm2.5': 12,
#   'pm2.5_avg': 9.7,
#   'pollutant': None,
#   'siteid': 9,
#   'sitename': '林口',
#   'so2': 0.8,
#   'so2_avg': 0,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 58,
#   'windspeed': 3.1},
#  {'aqi': 40,
#   'co': 0.32,
#   'co_8hr': 0.3,
#   'county': '新北市',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 25.06895,
#   'longitude': 121.481028,
#   'no': 0.7,
#   'no2': 10.1,
#   'nox': 10.8,
#   'o3': 43.9,
#   'o3_8hr': 35.6,
#   'pm10': 36,
#   'pm10_avg': 26,
#   'pm2.5': 16,
#   'pm2.5_avg': 12.2,
#   'pollutant': None,
#   'siteid': 8,
#   'sitename': '菜寮',
#   'so2': 0.7,
#   'so2_avg': 0,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 75,
#   'windspeed': 3.5},
#  {'aqi': 41,
#   'co': 0.28,
#   'co_8hr': 0.3,
#   'county': '新北市',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 25.037972,
#   'longitude': 121.4325,
#   'no': 0.6,
#   'no2': 6.9,
#   'nox': 7.5,
#   'o3': 44.9,
#   'o3_8hr': 34.4,
#   'pm10': 47,
#   'pm10_avg': 34,
#   'pm2.5': 17,
#   'pm2.5_avg': 12.7,
#   'pollutant': None,
#   'siteid': 7,
#   'sitename': '新莊',
#   'so2': 1.1,
#   'so2_avg': 0,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 68,
#   'windspeed': 5.7},
#  {'aqi': 34,
#   'co': 0.36,
#   'co_8hr': 0.3,
#   'county': '新北市',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 25.012972,
#   'longitude': 121.458667,
#   'no': 1,
#   'no2': 13.7,
#   'nox': 14.7,
#   'o3': 43.3,
#   'o3_8hr': 34.7,
#   'pm10': 41,
#   'pm10_avg': 29,
#   'pm2.5': 14,
#   'pm2.5_avg': 10.4,
#   'pollutant': None,
#   'siteid': 6,
#   'sitename': '板橋',
#   'so2': 1,
#   'so2_avg': 1,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 55,
#   'windspeed': 3},
#  {'aqi': 37,
#   'co': 0.35,
#   'co_8hr': 0.3,
#   'county': '新北市',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 24.982528,
#   'longitude': 121.451861,
#   'no': 0.6,
#   'no2': 11.6,
#   'nox': 12.3,
#   'o3': 40.4,
#   'o3_8hr': 32.4,
#   'pm10': 34,
#   'pm10_avg': 29,
#   'pm2.5': 10,
#   'pm2.5_avg': 11.5,
#   'pollutant': None,
#   'siteid': 5,
#   'sitename': '土城',
#   'so2': 1,
#   'so2_avg': 1,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 145,
#   'windspeed': 1.9},
#  {'aqi': 49,
#   'co': 0.33,
#   'co_8hr': 0.3,
#   'county': '新北市',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 24.977222,
#   'longitude': 121.537778,
#   'no': 0.7,
#   'no2': 10.1,
#   'nox': 10.9,
#   'o3': 37.7,
#   'o3_8hr': 29.2,
#   'pm10': 40,
#   'pm10_avg': 27,
#   'pm2.5': 17,
#   'pm2.5_avg': 15.1,
#   'pollutant': None,
#   'siteid': 4,
#   'sitename': '新店',
#   'so2': 0.6,
#   'so2_avg': 0,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 118,
#   'windspeed': 1.9},
#  {'aqi': 82,
#   'co': 0.23,
#   'co_8hr': 0.2,
#   'county': '新北市',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 25.179667,
#   'longitude': 121.689881,
#   'no': 0.5,
#   'no2': 2.9,
#   'nox': 3.5,
#   'o3': 53.9,
#   'o3_8hr': 48.2,
#   'pm10': 95,
#   'pm10_avg': 82,
#   'pm2.5': 17,
#   'pm2.5_avg': 16.3,
#   'pollutant': '懸浮微粒',
#   'siteid': 3,
#   'sitename': '萬里',
#   'so2': 0.1,
#   'so2_avg': 0,
#   'status': '普通',
#   'unit': None,
#   'winddirec': 45,
#   'windspeed': 5.9},
#  {'aqi': 39,
#   'co': 0.25,
#   'co_8hr': 0.2,
#   'county': '新北市',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 25.06624,
#   'longitude': 121.64081,
#   'no': 1.2,
#   'no2': 9.8,
#   'nox': 11,
#   'o3': 40.9,
#   'o3_8hr': 33.3,
#   'pm10': 38,
#   'pm10_avg': 28,
#   'pm2.5': 15,
#   'pm2.5_avg': 12,
#   'pollutant': None,
#   'siteid': 2,
#   'sitename': '汐止',
#   'so2': 1.7,
#   'so2_avg': 0,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 42,
#   'windspeed': 1.1},
#  {'aqi': 39,
#   'co': 0.24,
#   'co_8hr': 0.2,
#   'county': '基隆市',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 25.129167,
#   'longitude': 121.760056,
#   'no': 0.1,
#   'no2': 4,
#   'nox': 4.2,
#   'o3': 48.7,
#   'o3_8hr': 42.9,
#   'pm10': 41,
#   'pm10_avg': 31,
#   'pm2.5': 12,
#   'pm2.5_avg': 8.9,
#   'pollutant': None,
#   'siteid': 1,
#   'sitename': '基隆',
#   'so2': 1.2,
#   'so2_avg': 1,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 89,
#   'windspeed': 2.4},
#  {'aqi': 41,
#   'co': 0.24,
#   'co_8hr': 0.1,
#   'county': '屏東縣',
#   'datacreationdate': '2024-11-26 19:00',
#   'latitude': 22.260899,
#   'longitude': 120.651472,
#   'no': 0.2,
#   'no2': 2.7,
#   'nox': 2.9,
#   'o3': 39.7,
#   'o3_8hr': 44.4,
#   'pm10': 21,
#   'pm10_avg': 28,
#   'pm2.5': 6,
#   'pm2.5_avg': 9.2,
#   'pollutant': None,
#   'siteid': 313,
#   'sitename': '屏東(枋山)',
#   'so2': 0,
#   'so2_avg': 0,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 88,
#   'windspeed': 6.9},
#  {'aqi': 34,
#   'co': 0.34,
#   'co_8hr': 0.3,
#   'county': '花蓮縣',
#   'datacreationdate': '2024-11-26 19:00',
#   'latitude': 23.97709367,
#   'longitude': 121.61575076,
#   'no': 1.4,
#   'no2': 5.4,
#   'nox': 6.8,
#   'o3': 42.8,
#   'o3_8hr': 37.5,
#   'pm10': 25,
#   'pm10_avg': 25,
#   'pm2.5': 12,
#   'pm2.5_avg': 10.1,
#   'pollutant': None,
#   'siteid': 312,
#   'sitename': '花蓮（美崙）',
#   'so2': 0,
#   'so2_avg': 0,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 38,
#   'windspeed': 4.7},
#  {'aqi': 38,
#   'co': 0.43,
#   'co_8hr': 0.4,
#   'county': '新北市',
#   'datacreationdate': '2024-11-26 19:00',
#   'latitude': 24.94902778,
#   'longitude': 121.38352778,
#   'no': 8.5,
#   'no2': 23.7,
#   'nox': 32.2,
#   'o3': 26.8,
#   'o3_8hr': 21.1,
#   'pm10': 39,
#   'pm10_avg': 27,
#   'pm2.5': 14,
#   'pm2.5_avg': 10.5,
#   'pollutant': None,
#   'siteid': 311,
#   'sitename': '新北(樹林)',
#   'so2': 0.7,
#   'so2_avg': 0,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 140,
#   'windspeed': 0},
#  {'aqi': 57,
#   'co': 0.36,
#   'co_8hr': 0.3,
#   'county': '屏東縣',
#   'datacreationdate': '2024-11-26 19:00',
#   'latitude': 22.35222,
#   'longitude': 120.37722,
#   'no': 0.9,
#   'no2': 9.7,
#   'nox': 10.6,
#   'o3': 48.3,
#   'o3_8hr': 56.3,
#   'pm10': 55,
#   'pm10_avg': 47,
#   'pm2.5': 19,
#   'pm2.5_avg': 18,
#   'pollutant': '細懸浮微粒',
#   'siteid': 204,
#   'sitename': '屏東（琉球）',
#   'so2': 1.4,
#   'so2_avg': 2,
#   'status': '普通',
#   'unit': None,
#   'winddirec': 315,
#   'windspeed': 3.2},
#  {'aqi': 79,
#   'co': 0.41,
#   'co_8hr': 0.2,
#   'county': '臺南市',
#   'datacreationdate': '2024-11-26 19:00',
#   'latitude': 23.17904722,
#   'longitude': 120.24583056,
#   'no': 0.4,
#   'no2': 14,
#   'nox': 14.5,
#   'o3': 22.2,
#   'o3_8hr': 40.1,
#   'pm10': 105,
#   'pm10_avg': 79,
#   'pm2.5': 18,
#   'pm2.5_avg': 14,
#   'pollutant': '懸浮微粒',
#   'siteid': 203,
#   'sitename': '臺南（麻豆）',
#   'so2': 1.4,
#   'so2_avg': 1,
#   'status': '普通',
#   'unit': None,
#   'winddirec': 9,
#   'windspeed': 3.1},
#  {'aqi': 61,
#   'co': 0.4,
#   'co_8hr': 0.3,
#   'county': '高雄市',
#   'datacreationdate': '2024-11-26 19:00',
#   'latitude': 22.87985556,
#   'longitude': 120.24535,
#   'no': 0,
#   'no2': 14,
#   'nox': 13.9,
#   'o3': 32.1,
#   'o3_8hr': 43.3,
#   'pm10': 113,
#   'pm10_avg': 61,
#   'pm2.5': 12,
#   'pm2.5_avg': 8.5,
#   'pollutant': '懸浮微粒',
#   'siteid': 202,
#   'sitename': '高雄（湖內）',
#   'so2': 1.6,
#   'so2_avg': 1,
#   'status': '普通',
#   'unit': None,
#   'winddirec': 303,
#   'windspeed': 1.4},
#  {'aqi': 31,
#   'co': 0.4,
#   'co_8hr': 0.3,
#   'county': '彰化縣',
#   'datacreationdate': '2024-11-26 19:00',
#   'latitude': 23.96117,
#   'longitude': 120.56373,
#   'no': 2.1,
#   'no2': 13.7,
#   'nox': 15.8,
#   'o3': 22.7,
#   'o3_8hr': 33.5,
#   'pm10': 26,
#   'pm10_avg': 30,
#   'pm2.5': 9,
#   'pm2.5_avg': 8,
#   'pollutant': None,
#   'siteid': 201,
#   'sitename': '彰化（員林）',
#   'so2': 1.3,
#   'so2_avg': 1,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 352,
#   'windspeed': 1.9},
#  {'aqi': 39,
#   'co': 0.25,
#   'co_8hr': 0.2,
#   'county': '彰化縣',
#   'datacreationdate': '2024-11-26 19:00',
#   'latitude': 23.85493056,
#   'longitude': 120.26964167,
#   'no': 1,
#   'no2': 6,
#   'nox': 7.1,
#   'o3': 37.1,
#   'o3_8hr': 42.1,
#   'pm10': 24,
#   'pm10_avg': 30,
#   'pm2.5': 14,
#   'pm2.5_avg': 11,
#   'pollutant': None,
#   'siteid': 85,
#   'sitename': '大城',
#   'so2': 1.4,
#   'so2_avg': 1,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 45,
#   'windspeed': 9},
#  {'aqi': 48,
#   'co': 0.2,
#   'co_8hr': 0.2,
#   'county': '新北市',
#   'datacreationdate': '2024-11-26 19:00',
#   'latitude': 25.29681695,
#   'longitude': 121.53656894,
#   'no': 0.1,
#   'no2': 1.8,
#   'nox': 1.9,
#   'o3': 54.8,
#   'o3_8hr': 46.4,
#   'pm10': 54,
#   'pm10_avg': 48,
#   'pm2.5': 18,
#   'pm2.5_avg': 13,
#   'pollutant': None,
#   'siteid': 84,
#   'sitename': '富貴角',
#   'so2': 0.3,
#   'so2_avg': 0,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 51,
#   'windspeed': 10.7},
#  {'aqi': 70,
#   'co': 0.3,
#   'co_8hr': 0.3,
#   'county': '雲林縣',
#   'datacreationdate': '2024-11-26 19:00',
#   'latitude': 23.753506,
#   'longitude': 120.251825,
#   'no': 1,
#   'no2': 7.3,
#   'nox': 8.3,
#   'o3': 34.5,
#   'o3_8hr': 40.5,
#   'pm10': 62,
#   'pm10_avg': 70,
#   'pm2.5': 14,
#   'pm2.5_avg': 11.7,
#   'pollutant': '懸浮微粒',
#   'siteid': 83,
#   'sitename': '麥寮',
#   'so2': 1.2,
#   'so2_avg': 1,
#   'status': '普通',
#   'unit': None,
#   'winddirec': 3,
#   'windspeed': 7.4},
#  {'aqi': 39,
#   'co': 0.33,
#   'co_8hr': 0.2,
#   'county': '臺東縣',
#   'datacreationdate': '2024-11-26 19:00',
#   'latitude': 23.045083,
#   'longitude': 121.161933,
#   'no': 0.3,
#   'no2': 5.1,
#   'nox': 5.4,
#   'o3': 30.9,
#   'o3_8hr': 33.2,
#   'pm10': 16,
#   'pm10_avg': 39,
#   'pm2.5': 6,
#   'pm2.5_avg': 5.3,
#   'pollutant': None,
#   'siteid': 80,
#   'sitename': '關山',
#   'so2': 0.9,
#   'so2_avg': 1,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 37,
#   'windspeed': 2.6},
#  {'aqi': 35,
#   'co': 0.29,
#   'co_8hr': 0.3,
#   'county': '澎湖縣',
#   'datacreationdate': '2024-11-26 19:00',
#   'latitude': 23.569031,
#   'longitude': 119.566158,
#   'no': 0.8,
#   'no2': 3.4,
#   'nox': 4.2,
#   'o3': 41,
#   'o3_8hr': 38.2,
#   'pm10': 16,
#   'pm10_avg': 13,
#   'pm2.5': 9,
#   'pm2.5_avg': 5.2,
#   'pollutant': None,
#   'siteid': 78,
#   'sitename': '馬公',
#   'so2': 1.1,
#   'so2_avg': 1,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 39,
#   'windspeed': 7.3},
#  {'aqi': 46,
#   'co': 0.38,
#   'co_8hr': 0.3,
#   'county': '金門縣',
#   'datacreationdate': '2024-11-26 19:00',
#   'latitude': 24.432133,
#   'longitude': 118.312256,
#   'no': 0.8,
#   'no2': 6.8,
#   'nox': 7.7,
#   'o3': 37,
#   'o3_8hr': 50.4,
#   'pm10': 22,
#   'pm10_avg': 21,
#   'pm2.5': 11,
#   'pm2.5_avg': 8.4,
#   'pollutant': None,
#   'siteid': 77,
#   'sitename': '金門',
#   'so2': 0.8,
#   'so2_avg': 0,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 86,
#   'windspeed': 2.1},
#  {'aqi': 39,
#   'co': 0.27,
#   'co_8hr': 0.3,
#   'county': '連江縣',
#   'datacreationdate': '2024-11-26 19:00',
#   'latitude': 26.153736,
#   'longitude': 119.952724,
#   'no': 0.9,
#   'no2': 4.3,
#   'nox': 5.3,
#   'o3': 53,
#   'o3_8hr': 42.9,
#   'pm10': 34,
#   'pm10_avg': 24,
#   'pm2.5': 10,
#   'pm2.5_avg': 9.6,
#   'pollutant': None,
#   'siteid': 75,
#   'sitename': '馬祖',
#   'so2': 0.6,
#   'so2_avg': 0,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 330,
#   'windspeed': 1},
#  {'aqi': 47,
#   'co': 0.4,
#   'co_8hr': 0.2,
#   'county': '南投縣',
#   'datacreationdate': '2024-11-26 19:00',
#   'latitude': 23.968842,
#   'longitude': 120.967903,
#   'no': 1.2,
#   'no2': 11.2,
#   'nox': 12.4,
#   'o3': 33.7,
#   'o3_8hr': 36.2,
#   'pm10': 23,
#   'pm10_avg': 17,
#   'pm2.5': 15,
#   'pm2.5_avg': 14.5,
#   'pollutant': None,
#   'siteid': 72,
#   'sitename': '埔里',
#   'so2': 1.7,
#   'so2_avg': 1,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 310,
#   'windspeed': 0.5},
#  {'aqi': 56,
#   'co': 0.58,
#   'co_8hr': 0.4,
#   'county': '高雄市',
#   'datacreationdate': '2024-11-26 19:00',
#   'latitude': 22.608711,
#   'longitude': 120.312017,
#   'no': 1.8,
#   'no2': 21.2,
#   'nox': 23.1,
#   'o3': 33.8,
#   'o3_8hr': 43.1,
#   'pm10': 80,
#   'pm10_avg': 54,
#   'pm2.5': 19,
#   'pm2.5_avg': 17.5,
#   'pollutant': '細懸浮微粒',
#   'siteid': 71,
#   'sitename': '復興',
#   'so2': 1.5,
#   'so2_avg': 0,
#   'status': '普通',
#   'unit': None,
#   'winddirec': 282,
#   'windspeed': 2},
#  {'aqi': 34,
#   'co': 0.48,
#   'co_8hr': 0.4,
#   'county': '新北市',
#   'datacreationdate': '2024-11-26 19:00',
#   'latitude': 25.017,
#   'longitude': 121.516306,
#   'no': 3.6,
#   'no2': 15.4,
#   'nox': 19,
#   'o3': 36.7,
#   'o3_8hr': 29.7,
#   'pm10': 39,
#   'pm10_avg': 29,
#   'pm2.5': 14,
#   'pm2.5_avg': 10.4,
#   'pollutant': None,
#   'siteid': 70,
#   'sitename': '永和',
#   'so2': 1,
#   'so2_avg': 1,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 73,
#   'windspeed': 2.7},
#  {'aqi': 37,
#   'co': 0.43,
#   'co_8hr': 0.3,
#   'county': '南投縣',
#   'datacreationdate': '2024-11-26 19:00',
#   'latitude': 23.756389,
#   'longitude': 120.677306,
#   'no': 0.6,
#   'no2': 17.1,
#   'nox': 17.8,
#   'o3': 19,
#   'o3_8hr': 39.8,
#   'pm10': 33,
#   'pm10_avg': 28,
#   'pm2.5': 18,
#   'pm2.5_avg': 11.4,
#   'pollutant': None,
#   'siteid': 69,
#   'sitename': '竹山',
#   'so2': 0.8,
#   'so2_avg': 0,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 23,
#   'windspeed': 2},
#  {'aqi': 47,
#   'co': 0.8,
#   'co_8hr': 0.7,
#   'county': '桃園市',
#   'datacreationdate': '2024-11-26 19:00',
#   'latitude': 24.953278,
#   'longitude': 121.221667,
#   'no': 20.9,
#   'no2': 28,
#   'nox': 49,
#   'o3': 22.9,
#   'o3_8hr': 16.2,
#   'pm10': 41,
#   'pm10_avg': 27,
#   'pm2.5': 14,
#   'pm2.5_avg': 12,
#   'pollutant': None,
#   'siteid': 68,
#   'sitename': '中壢',
#   'so2': 0.7,
#   'so2_avg': 0,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 307,
#   'windspeed': 1.2},
#  {'aqi': 55,
#   'co': 1.16,
#   'co_8hr': 1,
#   'county': '新北市',
# ...
#   'county': '高雄市',
#   'datacreationdate': '2024-11-26 14:00',
#   'latitude': 22.63390278,
#   'longitude': 120.28676111,
#   'no': 2.6,
#   'no2': 11,
#   'nox': 13.6,
#   'o3': 48.2,
#   'o3_8hr': 31.9,
#   'pm10': 47,
#   'pm10_avg': 52,
#   'pm2.5': 16,
#   'pm2.5_avg': 16.6,
#   'pollutant': '細懸浮微粒',
#   'siteid': 56,
#   'sitename': '前金',
#   'so2': 1.1,
#   'so2_avg': 0,
#   'status': '普通',
#   'unit': None,
#   'winddirec': 356,
#   'windspeed': 4.1},
#  {'aqi': 55,
#   'co': 0.25,
#   'co_8hr': 0.2,
#   'county': '高雄市',
#   'datacreationdate': '2024-11-26 14:00',
#   'latitude': 22.674861,
#   'longitude': 120.292917,
#   'no': 1.2,
#   'no2': 6.3,
#   'nox': 7.5,
#   'o3': 52.6,
#   'o3_8hr': 33.6,
#   'pm10': 41,
#   'pm10_avg': 43,
#   'pm2.5': 19,
#   'pm2.5_avg': 17,
#   'pollutant': '細懸浮微粒',
#   'siteid': 54,
#   'sitename': '左營',
#   'so2': 1.3,
#   'so2_avg': 0,
#   'status': '普通',
#   'unit': None,
#   'winddirec': 359,
#   'windspeed': 4},
#  {'aqi': 48,
#   'co': 0.22,
#   'co_8hr': 0.2,
#   'county': '高雄市',
#   'datacreationdate': '2024-11-26 14:00',
#   'latitude': 22.733667,
#   'longitude': 120.328289,
#   'no': 1.1,
#   'no2': 8.8,
#   'nox': 9.9,
#   'o3': 51.9,
#   'o3_8hr': 32.4,
#   'pm10': 41,
#   'pm10_avg': 46,
#   'pm2.5': 14,
#   'pm2.5_avg': 14.8,
#   'pollutant': None,
#   'siteid': 53,
#   'sitename': '楠梓',
#   'so2': 1.4,
#   'so2_avg': 1,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 25,
#   'windspeed': 2.6},
#  {'aqi': 62,
#   'co': 0.29,
#   'co_8hr': 0.2,
#   'county': '高雄市',
#   'datacreationdate': '2024-11-26 14:00',
#   'latitude': 22.4795,
#   'longitude': 120.41175,
#   'no': 0.8,
#   'no2': 8.8,
#   'nox': 9.7,
#   'o3': 50.6,
#   'o3_8hr': 34.3,
#   'pm10': 29,
#   'pm10_avg': 40,
#   'pm2.5': 11,
#   'pm2.5_avg': 20.1,
#   'pollutant': '細懸浮微粒',
#   'siteid': 52,
#   'sitename': '林園',
#   'so2': 2,
#   'so2_avg': 1,
#   'status': '普通',
#   'unit': None,
#   'winddirec': 1,
#   'windspeed': 2.1},
#  {'aqi': 57,
#   'co': 0.2,
#   'co_8hr': 0.2,
#   'county': '高雄市',
#   'datacreationdate': '2024-11-26 14:00',
#   'latitude': 22.56413611,
#   'longitude': 120.425311,
#   'no': 1.2,
#   'no2': 8.7,
#   'nox': 9.9,
#   'o3': 48.9,
#   'o3_8hr': 30.9,
#   'pm10': 20,
#   'pm10_avg': 24,
#   'pm2.5': 13,
#   'pm2.5_avg': 17.8,
#   'pollutant': '細懸浮微粒',
#   'siteid': 51,
#   'sitename': '大寮',
#   'so2': 1,
#   'so2_avg': 2,
#   'status': '普通',
#   'unit': None,
#   'winddirec': 359,
#   'windspeed': 1.7},
#  {'aqi': 59,
#   'co': 0.37,
#   'co_8hr': 0.4,
#   'county': '高雄市',
#   'datacreationdate': '2024-11-26 14:00',
#   'latitude': 22.628126,
#   'longitude': 120.357422,
#   'no': 2.8,
#   'no2': 12.1,
#   'nox': 15,
#   'o3': 45.4,
#   'o3_8hr': 28.8,
#   'pm10': 43,
#   'pm10_avg': 41,
#   'pm2.5': 14,
#   'pm2.5_avg': 18.9,
#   'pollutant': '細懸浮微粒',
#   'siteid': 50,
#   'sitename': '鳳山',
#   'so2': 0.7,
#   'so2_avg': 1,
#   'status': '普通',
#   'unit': None,
#   'winddirec': 269,
#   'windspeed': 1.5},
#  {'aqi': 59,
#   'co': 0.25,
#   'co_8hr': 0.2,
#   'county': '高雄市',
#   'datacreationdate': '2024-11-26 14:00',
#   'latitude': 22.689056,
#   'longitude': 120.332631,
#   'no': 2.2,
#   'no2': 8.9,
#   'nox': 11.1,
#   'o3': 49.3,
#   'o3_8hr': 29.4,
#   'pm10': 29,
#   'pm10_avg': 36,
#   'pm2.5': 15,
#   'pm2.5_avg': 18.6,
#   'pollutant': '細懸浮微粒',
#   'siteid': 49,
#   'sitename': '仁武',
#   'so2': 1.2,
#   'so2_avg': 1,
#   'status': '普通',
#   'unit': None,
#   'winddirec': 345,
#   'windspeed': 3.2},
#  {'aqi': 52,
#   'co': 0.22,
#   'co_8hr': 0.2,
#   'county': '高雄市',
#   'datacreationdate': '2024-11-26 14:00',
#   'latitude': 22.757506,
#   'longitude': 120.305689,
#   'no': 1.6,
#   'no2': 8.7,
#   'nox': 10.3,
#   'o3': 50.1,
#   'o3_8hr': 32.2,
#   'pm10': 31,
#   'pm10_avg': 40,
#   'pm2.5': 11,
#   'pm2.5_avg': 16,
#   'pollutant': '細懸浮微粒',
#   'siteid': 48,
#   'sitename': '橋頭',
#   'so2': 1.4,
#   'so2_avg': 1,
#   'status': '普通',
#   'unit': None,
#   'winddirec': 10,
#   'windspeed': 2.9},
#  {'aqi': 33,
#   'co': 0.2,
#   'co_8hr': 0.2,
#   'county': '高雄市',
#   'datacreationdate': '2024-11-26 14:00',
#   'latitude': 22.883583,
#   'longitude': 120.530542,
#   'no': 1.1,
#   'no2': 3.9,
#   'nox': 5,
#   'o3': 46,
#   'o3_8hr': 29.9,
#   'pm10': 19,
#   'pm10_avg': 23,
#   'pm2.5': 7,
#   'pm2.5_avg': 10.1,
#   'pollutant': None,
#   'siteid': 47,
#   'sitename': '美濃',
#   'so2': 1.1,
#   'so2_avg': 1,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 293,
#   'windspeed': 1.5},
#  {'aqi': 35,
#   'co': 0.24,
#   'co_8hr': 0.2,
#   'county': '臺南市',
#   'datacreationdate': '2024-11-26 14:00',
#   'latitude': 22.98928311,
#   'longitude': 120.21947897,
#   'no': 0.6,
#   'no2': 7.1,
#   'nox': 7.8,
#   'o3': 48.6,
#   'o3_8hr': 32,
#   'pm10': 39,
#   'pm10_avg': 35,
#   'pm2.5': 11,
#   'pm2.5_avg': 8.8,
#   'pollutant': None,
#   'siteid': 46,
#   'sitename': '臺南',
#   'so2': 1.3,
#   'so2_avg': 0,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 15,
#   'windspeed': 2.8},
#  {'aqi': 43,
#   'co': 0.26,
#   'co_8hr': 0.2,
#   'county': '臺南市',
#   'datacreationdate': '2024-11-26 14:00',
#   'latitude': 23.048197,
#   'longitude': 120.2175,
#   'no': 1.3,
#   'no2': 5.9,
#   'nox': 7.3,
#   'o3': 48.4,
#   'o3_8hr': 32.4,
#   'pm10': 44,
#   'pm10_avg': 43,
#   'pm2.5': 10,
#   'pm2.5_avg': 12.5,
#   'pollutant': None,
#   'siteid': 45,
#   'sitename': '安南',
#   'so2': 1.1,
#   'so2_avg': 0,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 328,
#   'windspeed': 3.6},
#  {'aqi': 40,
#   'co': 0.19,
#   'co_8hr': 0.1,
#   'county': '臺南市',
#   'datacreationdate': '2024-11-26 14:00',
#   'latitude': 23.11337642,
#   'longitude': 120.29740529,
#   'no': 1.2,
#   'no2': 3.9,
#   'nox': 5.1,
#   'o3': 49.6,
#   'o3_8hr': 32.7,
#   'pm10': 39,
#   'pm10_avg': 40,
#   'pm2.5': 7,
#   'pm2.5_avg': 9.2,
#   'pollutant': None,
#   'siteid': 44,
#   'sitename': '善化',
#   'so2': 1.4,
#   'so2_avg': 1,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 8,
#   'windspeed': 5.2},
#  {'aqi': 45,
#   'co': 0.25,
#   'co_8hr': 0.2,
#   'county': '臺南市',
#   'datacreationdate': '2024-11-26 14:00',
#   'latitude': 23.305633,
#   'longitude': 120.31725,
#   'no': 1.4,
#   'no2': 6.7,
#   'nox': 8.2,
#   'o3': 46.8,
#   'o3_8hr': 30.3,
#   'pm10': 49,
#   'pm10_avg': 45,
#   'pm2.5': 13,
#   'pm2.5_avg': 10.5,
#   'pollutant': None,
#   'siteid': 43,
#   'sitename': '新營',
#   'so2': 1.2,
#   'so2_avg': 1,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 25,
#   'windspeed': 3.4},
#  {'aqi': 36,
#   'co': 0.24,
#   'co_8hr': 0.2,
#   'county': '嘉義市',
#   'datacreationdate': '2024-11-26 14:00',
#   'latitude': 23.46477865,
#   'longitude': 120.44125148,
#   'no': 1.1,
#   'no2': 4.4,
#   'nox': 5.5,
#   'o3': 51.1,
#   'o3_8hr': 30.9,
#   'pm10': 33,
#   'pm10_avg': 35,
#   'pm2.5': 8,
#   'pm2.5_avg': 11.1,
#   'pollutant': None,
#   'siteid': 42,
#   'sitename': '嘉義',
#   'so2': 1.1,
#   'so2_avg': 2,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 13,
#   'windspeed': 2.5},
#  {'aqi': 34,
#   'co': 0.32,
#   'co_8hr': 0.2,
#   'county': '雲林縣',
#   'datacreationdate': '2024-11-26 14:00',
#   'latitude': 23.702175,
#   'longitude': 120.19933333,
#   'no': 1.6,
#   'no2': 7.3,
#   'nox': 9,
#   'o3': 42.7,
#   'o3_8hr': 31.8,
#   'pm10': 37,
#   'pm10_avg': 34,
#   'pm2.5': 6,
#   'pm2.5_avg': 5.2,
#   'pollutant': None,
#   'siteid': 41,
#   'sitename': '臺西',
#   'so2': 1.6,
#   'so2_avg': 1,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 19,
#   'windspeed': 6.8},
#  {'aqi': 50,
#   'co': 0.23,
#   'co_8hr': 0.2,
#   'county': '嘉義縣',
#   'datacreationdate': '2024-11-26 14:00',
#   'latitude': 23.46538,
#   'longitude': 120.2478,
#   'no': 2.4,
#   'no2': 4.6,
#   'nox': 7,
#   'o3': 46.7,
#   'o3_8hr': 31.2,
#   'pm10': 38,
#   'pm10_avg': 50,
#   'pm2.5': 10,
#   'pm2.5_avg': 7.3,
#   'pollutant': None,
#   'siteid': 40,
#   'sitename': '朴子',
#   'so2': 1.4,
#   'so2_avg': 1,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 345,
#   'windspeed': 2.8},
#  {'aqi': 34,
#   'co': 0.22,
#   'co_8hr': 0.1,
#   'county': '嘉義縣',
#   'datacreationdate': '2024-11-26 14:00',
#   'latitude': 23.554839,
#   'longitude': 120.345531,
#   'no': 0.9,
#   'no2': 6.1,
#   'nox': 7.1,
#   'o3': 49,
#   'o3_8hr': 32.6,
#   'pm10': 26,
#   'pm10_avg': 34,
#   'pm2.5': 14,
#   'pm2.5_avg': 8.9,
#   'pollutant': None,
#   'siteid': 39,
#   'sitename': '新港',
#   'so2': 1.8,
#   'so2_avg': 1,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 7,
#   'windspeed': 3.5},
#  {'aqi': 63,
#   'co': 0.31,
#   'co_8hr': 0.2,
#   'county': '雲林縣',
#   'datacreationdate': '2024-11-26 14:00',
#   'latitude': 23.757547,
#   'longitude': 120.348742,
#   'no': 1.2,
#   'no2': 5.1,
#   'nox': 6.4,
#   'o3': 46.4,
#   'o3_8hr': 28,
#   'pm10': 33,
#   'pm10_avg': 63,
#   'pm2.5': 8,
#   'pm2.5_avg': 9.8,
#   'pollutant': '懸浮微粒',
#   'siteid': 38,
#   'sitename': '崙背',
#   'so2': 1.1,
#   'so2_avg': 1,
#   'status': '普通',
#   'unit': None,
#   'winddirec': 323,
#   'windspeed': 2.5},
#  {'aqi': 41,
#   'co': 0.24,
#   'co_8hr': 0.2,
#   'county': '雲林縣',
#   'datacreationdate': '2024-11-26 14:00',
#   'latitude': 23.711853,
#   'longitude': 120.544994,
#   'no': 0.9,
#   'no2': 4.6,
#   'nox': 5.6,
#   'o3': 52.3,
#   'o3_8hr': 31.3,
#   'pm10': 16,
#   'pm10_avg': 41,
#   'pm2.5': 5,
#   'pm2.5_avg': 8.1,
#   'pollutant': None,
#   'siteid': 37,
#   'sitename': '斗六',
#   'so2': 1.2,
#   'so2_avg': 1,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 10,
#   'windspeed': 1.5},
#  {'aqi': 27,
#   'co': 0.28,
#   'co_8hr': 0.3,
#   'county': '南投縣',
#   'datacreationdate': '2024-11-26 14:00',
#   'latitude': 23.913,
#   'longitude': 120.685306,
#   'no': 1.8,
#   'no2': 7.5,
#   'nox': 9.4,
#   'o3': 48.3,
#   'o3_8hr': 26.4,
#   'pm10': 9,
#   'pm10_avg': 19,
#   'pm2.5': 4,
#   'pm2.5_avg': 8.3,
#   'pollutant': None,
#   'siteid': 36,
#   'sitename': '南投',
#   'so2': 1.2,
#   'so2_avg': 1,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 221,
#   'windspeed': 1.6},
#  {'aqi': 29,
#   'co': 0.34,
#   'co_8hr': 0.2,
#   'county': '彰化縣',
#   'datacreationdate': '2024-11-26 14:00',
#   'latitude': 23.925175,
#   'longitude': 120.409653,
#   'no': 1.4,
#   'no2': 6.1,
#   'nox': 7.5,
#   'o3': 49.4,
#   'o3_8hr': 31.5,
#   'pm10': 24,
#   'pm10_avg': 26,
#   'pm2.5': 6,
#   'pm2.5_avg': 6.2,
#   'pollutant': None,
#   'siteid': 35,
#   'sitename': '二林',
#   'so2': 1,
#   'so2_avg': 1,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 352,
#   'windspeed': 4.9},
#  {'aqi': 26,
#   'co': 0.36,
#   'co_8hr': 0.2,
#   'county': '彰化縣',
#   'datacreationdate': '2024-11-26 14:00',
#   'latitude': 24.131672,
#   'longitude': 120.469061,
#   'no': 2.4,
#   'no2': 8.6,
#   'nox': 11,
#   'o3': 39.8,
#   'o3_8hr': 28.8,
#   'pm10': 22,
#   'pm10_avg': 17,
#   'pm2.5': 3,
#   'pm2.5_avg': 5,
#   'pollutant': None,
#   'siteid': 34,
#   'sitename': '線西',
#   'so2': 1.9,
#   'so2_avg': 1,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 14,
#   'windspeed': 7.4},
#  {'aqi': 22,
#   'co': 0.34,
#   'co_8hr': 0.3,
#   'county': '彰化縣',
#   'datacreationdate': '2024-11-26 14:00',
#   'latitude': 24.066,
#   'longitude': 120.541519,
#   'no': None,
#   'no2': None,
#   'nox': None,
#   'o3': 30.1,
#   'o3_8hr': 24.6,
#   'pm10': None,
#   'pm10_avg': 13,
#   'pm2.5': None,
#   'pm2.5_avg': 6.8,
#   'pollutant': None,
#   'siteid': 33,
#   'sitename': '彰化',
#   'so2': 0.4,
#   'so2_avg': 0,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 5,
#   'windspeed': 2.7},
#  {'aqi': 24,
#   'co': 0.3,
#   'co_8hr': 0.2,
#   'county': '臺中市',
#   'datacreationdate': '2024-11-26 14:00',
#   'latitude': 24.162197,
#   'longitude': 120.616917,
#   'no': 2.6,
#   'no2': 8.1,
#   'nox': 10.7,
#   'o3': 38.6,
#   'o3_8hr': 27,
#   'pm10': 15,
#   'pm10_avg': 22,
#   'pm2.5': 4,
#   'pm2.5_avg': 6.1,
#   'pollutant': None,
#   'siteid': 32,
#   'sitename': '西屯',
#   'so2': 1,
#   'so2_avg': 1,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 352,
#   'windspeed': 4.4},
#  {'aqi': 23,
#   'co': 0.36,
#   'co_8hr': 0.2,
#   'county': '臺中市',
#   'datacreationdate': '2024-11-26 14:00',
#   'latitude': 24.151958,
#   'longitude': 120.641092,
#   'no': 3.5,
#   'no2': 10.1,
#   'nox': 13.7,
#   'o3': 37.2,
#   'o3_8hr': 25.9,
#   'pm10': 10,
#   'pm10_avg': 14,
#   'pm2.5': 4,
#   'pm2.5_avg': 5.9,
#   'pollutant': None,
#   'siteid': 31,
#   'sitename': '忠明',
#   'so2': 1.2,
#   'so2_avg': 1,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 283,
#   'windspeed': 2.2},
#  {'aqi': 25,
#   'co': 0.36,
#   'co_8hr': 0.2,
#   'county': '臺中市',
#   'datacreationdate': '2024-11-26 14:00',
#   'latitude': 24.09961111,
#   'longitude': 120.67844444,
#   'no': 3.2,
#   'no2': 9.4,
#   'nox': 12.6,
#   'o3': 40.6,
#   'o3_8hr': 27.2,
#   'pm10': 9,
#   'pm10_avg': 15,
#   'pm2.5': 4,
#   'pm2.5_avg': 7.7,
#   'pollutant': None,
#   'siteid': 30,
#   'sitename': '大里',
#   'so2': 1.3,
#   'so2_avg': 1,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 297,
#   'windspeed': 3.1},
#  {'aqi': 25,
#   'co': 0.32,
#   'co_8hr': 0.2,
#   'county': '臺中市',
#   'datacreationdate': '2024-11-26 14:00',
#   'latitude': 24.225628,
#   'longitude': 120.568794,
#   'no': 2.1,
#   'no2': 6.5,
#   'nox': 8.6,
#   'o3': 40.6,
#   'o3_8hr': 27.7,
#   'pm10': 9,
#   'pm10_avg': 15,
#   'pm2.5': 6,
#   'pm2.5_avg': 5.7,
#   'pollutant': None,
#   'siteid': 29,
#   'sitename': '沙鹿',
#   'so2': 0.9,
#   'so2_avg': 1,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 338,
#   'windspeed': 5.2},
#  {'aqi': 28,
#   'co': 0.3,
#   'co_8hr': 0.2,
#   'county': '臺中市',
#   'datacreationdate': '2024-11-26 14:00',
#   'latitude': 24.25699731,
#   'longitude': 120.74252414,
#   'no': 1.2,
#   'no2': 5.1,
#   'nox': 6.3,
#   'o3': 40.2,
#   'o3_8hr': 30.6,
#   'pm10': 8,
#   'pm10_avg': 9,
#   'pm2.5': 4,
#   'pm2.5_avg': 7.4,
#   'pollutant': None,
#   'siteid': 28,
#   'sitename': '豐原',
#   'so2': 1,
#   'so2_avg': 1,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 330,
#   'windspeed': 3.8},
#  {'aqi': 23,
#   'co': 0.31,
#   'co_8hr': 0.2,
#   'county': '苗栗縣',
#   'datacreationdate': '2024-11-26 14:00',
#   'latitude': 24.38248443,
#   'longitude': 120.75956754,
#   'no': 2.3,
#   'no2': 4.3,
#   'nox': 6.6,
#   'o3': 33.8,
#   'o3_8hr': 25.2,
#   'pm10': 9,
#   'pm10_avg': 8,
#   'pm2.5': 2,
#   'pm2.5_avg': 3.9,
#   'pollutant': None,
#   'siteid': 27,
#   'sitename': '三義',
#   'so2': 0.8,
#   'so2_avg': 0,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 12,
#   'windspeed': 6.2},
#  {'aqi': 19,
#   'co': 0.32,
#   'co_8hr': 0.2,
#   'county': '苗栗縣',
#   'datacreationdate': '2024-11-26 14:00',
#   'latitude': 24.56499183,
#   'longitude': 120.82011468,
#   'no': 2.3,
#   'no2': 6,
#   'nox': 8.3,
#   'o3': 32.2,
#   'o3_8hr': 21.4,
#   'pm10': 9,
#   'pm10_avg': 12,
#   'pm2.5': 3,
#   'pm2.5_avg': 4.9,
#   'pollutant': None,
#   'siteid': 26,
#   'sitename': '苗栗',
#   'so2': 1.2,
#   'so2_avg': 1,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 6,
#   'windspeed': 5},
#  {'aqi': 19,
#   'co': 0.36,
#   'co_8hr': 0.3,
#   'county': '苗栗縣',
#   'datacreationdate': '2024-11-26 14:00',
#   'latitude': 24.69690679,
#   'longitude': 120.89869286,
#   'no': 3.6,
#   'no2': 6.9,
#   'nox': 10.6,
#   'o3': 28.8,
#   'o3_8hr': 21.5,
#   'pm10': 6,
#   'pm10_avg': 10,
#   'pm2.5': 6,
#   'pm2.5_avg': 5.8,
#   'pollutant': None,
#   'siteid': 25,
#   'sitename': '頭份',
#   'so2': 1.8,
#   'so2_avg': 1,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 10,
#   'windspeed': 4.6},
#  {'aqi': 19,
#   'co': 0.39,
#   'co_8hr': 0.3,
#   'county': '新竹市',
#   'datacreationdate': '2024-11-26 14:00',
#   'latitude': 24.8056356,
#   'longitude': 120.97236752,
#   'no': 3.1,
#   'no2': 9.7,
#   'nox': 12.8,
#   'o3': 24.7,
#   'o3_8hr': 21.8,
#   'pm10': 4,
#   'pm10_avg': 8,
#   'pm2.5': 4,
#   'pm2.5_avg': 3.3,
#   'pollutant': None,
#   'siteid': 24,
#   'sitename': '新竹',
#   'so2': 1.4,
#   'so2_avg': 1,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 28,
#   'windspeed': 4.4},
#  {'aqi': 19,
#   'co': 0.32,
#   'co_8hr': 0.2,
#   'county': '新竹縣',
#   'datacreationdate': '2024-11-26 14:00',
#   'latitude': 24.74091408,
#   'longitude': 121.08895493,
#   'no': 1.7,
#   'no2': 5,
#   'nox': 6.7,
#   'o3': 31.4,
#   'o3_8hr': 21.2,
#   'pm10': 7,
#   'pm10_avg': 9,
#   'pm2.5': 0,
#   'pm2.5_avg': 4.4,
#   'pollutant': None,
#   'siteid': 23,
#   'sitename': '竹東',
#   'so2': 0.3,
#   'so2_avg': 0,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 19,
#   'windspeed': 3.1},
#  {'aqi': 21,
#   'co': 0.38,
#   'co_8hr': 0.3,
#   'county': '新竹縣',
#   'datacreationdate': '2024-11-26 14:00',
#   'latitude': 24.90009696,
#   'longitude': 121.03886894,
#   'no': 2,
#   'no2': 8.9,
#   'nox': 10.9,
#   'o3': 22.8,
#   'o3_8hr': 23,
#   'pm10': 8,
#   'pm10_avg': 9,
#   'pm2.5': 5,
#   'pm2.5_avg': 5.2,
#   'pollutant': None,
#   'siteid': 22,
#   'sitename': '湖口',
#   'so2': 2.5,
#   'so2_avg': 1,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 37,
#   'windspeed': 6},
#  {'aqi': 20,
#   'co': 0.34,
#   'co_8hr': 0.3,
#   'county': '桃園市',
#   'datacreationdate': '2024-11-26 14:00',
#   'latitude': 24.86400048,
#   'longitude': 121.21645772,
#   'no': 2.3,
#   'no2': 5.9,
#   'nox': 8.2,
#   'o3': 30.6,
#   'o3_8hr': 20.9,
#   'pm10': 14,
#   'pm10_avg': 11,
#   'pm2.5': 4,
#   'pm2.5_avg': 6.3,
#   'pollutant': None,
#   'siteid': 21,
#   'sitename': '龍潭',
#   'so2': 1,
#   'so2_avg': 1,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 57,
#   'windspeed': 6.4}]

# %%
for site in sheets:
    if site['sitename'] == '永和':
        print(site)
# Out:
# {'sitename': '永和', 'county': '新北市', 'aqi': 35, 'pollutant': None, 'status': '良好', 'so2': 1.1, 'co': 0.44, 'o3': 37.8, 'o3_8hr': 32, 'pm10': 40, 'pm2.5': 12, 'no2': 13.6, 'nox': 16.5, 'no': 2.9, 'windspeed': 2.2, 'winddirec': 82, 'datacreationdate': '2024-11-26 20:00', 'unit': None, 'co_8hr': 0.4, 'pm2.5_avg': 10.7, 'pm10_avg': 32, 'so2_avg': 1, 'longitude': 121.516306, 'latitude': 25.017, 'siteid': 70}
# {'sitename': '永和', 'county': '新北市', 'aqi': 34, 'pollutant': None, 'status': '良好', 'so2': 1, 'co': 0.48, 'o3': 36.7, 'o3_8hr': 29.7, 'pm10': 39, 'pm2.5': 14, 'no2': 15.4, 'nox': 19, 'no': 3.6, 'windspeed': 2.7, 'winddirec': 73, 'datacreationdate': '2024-11-26 19:00', 'unit': None, 'co_8hr': 0.4, 'pm2.5_avg': 10.4, 'pm10_avg': 29, 'so2_avg': 1, 'longitude': 121.516306, 'latitude': 25.017, 'siteid': 70}
# {'sitename': '永和', 'county': '新北市', 'aqi': 34, 'pollutant': None, 'status': '良好', 'so2': 1, 'co': 0.48, 'o3': 36.7, 'o3_8hr': 29.7, 'pm10': 39, 'pm2.5': 14, 'no2': 15.4, 'nox': 19, 'no': 3.6, 'windspeed': 2.7, 'winddirec': 73, 'datacreationdate': '2024-11-26 19:00', 'unit': None, 'co_8hr': 0.4, 'pm2.5_avg': 10.4, 'pm10_avg': 29, 'so2_avg': 1, 'longitude': 121.516306, 'latitude': 25.017, 'siteid': 70}
# {'sitename': '永和', 'county': '新北市', 'aqi': 31, 'pollutant': None, 'status': '良好', 'so2': 1.1, 'co': 0.49, 'o3': 36.2, 'o3_8hr': 27.1, 'pm10': 44, 'pm2.5': 15, 'no2': 14.8, 'nox': 18.1, 'no': 3.2, 'windspeed': 1.7, 'winddirec': 77, 'datacreationdate': '2024-11-26 18:00', 'unit': None, 'co_8hr': 0.4, 'pm2.5_avg': 9.5, 'pm10_avg': 27, 'so2_avg': 1, 'longitude': 121.516306, 'latitude': 25.017, 'siteid': 70}
# {'sitename': '永和', 'county': '新北市', 'aqi': 31, 'pollutant': None, 'status': '良好', 'so2': 1.1, 'co': 0.49, 'o3': 36.2, 'o3_8hr': 27.1, 'pm10': 44, 'pm2.5': 15, 'no2': 14.8, 'nox': 18.1, 'no': 3.2, 'windspeed': 1.7, 'winddirec': 77, 'datacreationdate': '2024-11-26 18:00', 'unit': None, 'co_8hr': 0.4, 'pm2.5_avg': 9.5, 'pm10_avg': 27, 'so2_avg': 1, 'longitude': 121.516306, 'latitude': 25.017, 'siteid': 70}
# {'sitename': '永和', 'county': '新北市', 'aqi': 28, 'pollutant': None, 'status': '良好', 'so2': 1, 'co': 0.4, 'o3': 32.7, 'o3_8hr': 24.4, 'pm10': 40, 'pm2.5': 11, 'no2': 15, 'nox': 20.5, 'no': 5.4, 'windspeed': 2.4, 'winddirec': 75, 'datacreationdate': '2024-11-26 17:00', 'unit': None, 'co_8hr': 0.4, 'pm2.5_avg': 8.5, 'pm10_avg': 23, 'so2_avg': 1, 'longitude': 121.516306, 'latitude': 25.017, 'siteid': 70}
# {'sitename': '永和', 'county': '新北市', 'aqi': 28, 'pollutant': None, 'status': '良好', 'so2': 1, 'co': 0.4, 'o3': 32.7, 'o3_8hr': 24.4, 'pm10': 40, 'pm2.5': 11, 'no2': 15, 'nox': 20.5, 'no': 5.4, 'windspeed': 2.4, 'winddirec': 75, 'datacreationdate': '2024-11-26 17:00', 'unit': None, 'co_8hr': 0.4, 'pm2.5_avg': 8.5, 'pm10_avg': 23, 'so2_avg': 1, 'longitude': 121.516306, 'latitude': 25.017, 'siteid': 70}
# {'sitename': '永和', 'county': '新北市', 'aqi': 24, 'pollutant': None, 'status': '良好', 'so2': 0.9, 'co': 0.37, 'o3': 33.5, 'o3_8hr': 21.5, 'pm10': 30, 'pm2.5': 11, 'no2': 10.3, 'nox': 13.6, 'no': 3.2, 'windspeed': 2.7, 'winddirec': 90, 'datacreationdate': '2024-11-26 16:00', 'unit': None, 'co_8hr': 0.5, 'pm2.5_avg': 7.5, 'pm10_avg': 19, 'so2_avg': 1, 'longitude': 121.516306, 'latitude': 25.017, 'siteid': 70}
# {'sitename': '永和', 'county': '新北市', 'aqi': 24, 'pollutant': None, 'status': '良好', 'so2': 0.9, 'co': 0.37, 'o3': 33.5, 'o3_8hr': 21.5, 'pm10': 30, 'pm2.5': 11, 'no2': 10.3, 'nox': 13.6, 'no': 3.2, 'windspeed': 2.7, 'winddirec': 90, 'datacreationdate': '2024-11-26 16:00', 'unit': None, 'co_8hr': 0.5, 'pm2.5_avg': 7.5, 'pm10_avg': 19, 'so2_avg': 1, 'longitude': 121.516306, 'latitude': 25.017, 'siteid': 70}
# {'sitename': '永和', 'county': '新北市', 'aqi': 22, 'pollutant': None, 'status': '良好', 'so2': 0.9, 'co': 0.41, 'o3': 30.2, 'o3_8hr': 18.6, 'pm10': 27, 'pm2.5': 8, 'no2': 10.3, 'nox': 14.5, 'no': 4.2, 'windspeed': 3.6, 'winddirec': 67, 'datacreationdate': '2024-11-26 15:00', 'unit': None, 'co_8hr': 0.7, 'pm2.5_avg': 6.7, 'pm10_avg': 15, 'so2_avg': 1, 'longitude': 121.516306, 'latitude': 25.017, 'siteid': 70}
# {'sitename': '永和', 'county': '新北市', 'aqi': 22, 'pollutant': None, 'status': '良好', 'so2': 0.9, 'co': 0.41, 'o3': 30.2, 'o3_8hr': 18.6, 'pm10': 27, 'pm2.5': 8, 'no2': 10.3, 'nox': 14.5, 'no': 4.2, 'windspeed': 3.6, 'winddirec': 67, 'datacreationdate': '2024-11-26 15:00', 'unit': None, 'co_8hr': 0.7, 'pm2.5_avg': 6.7, 'pm10_avg': 15, 'so2_avg': 1, 'longitude': 121.516306, 'latitude': 25.017, 'siteid': 70}
# {'sitename': '永和', 'county': '新北市', 'aqi': 20, 'pollutant': None, 'status': '良好', 'so2': 0.9, 'co': 0.48, 'o3': 25.3, 'o3_8hr': 16.5, 'pm10': 21, 'pm2.5': 9, 'no2': 10.4, 'nox': 15.2, 'no': 4.7, 'windspeed': 3.3, 'winddirec': 81, 'datacreationdate': '2024-11-26 14:00', 'unit': None, 'co_8hr': 0.7, 'pm2.5_avg': 6.2, 'pm10_avg': 13, 'so2_avg': 1, 'longitude': 121.516306, 'latitude': 25.017, 'siteid': 70}
